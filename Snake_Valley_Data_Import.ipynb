# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import os
import glob
import xmltodict
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import matplotlib.ticker as tick
import seaborn as sns
import scipy.stats as sp
import statsmodels.api as sm
import statsmodels.tsa.tsatools as tools
from pandas.stats.api import ols
from datetime import datetime
from pylab import rcParams
rcParams['figure.figsize'] = 15, 10

# %% [markdown]
# ## Import Relevant Data

# %% [markdown]
# ### Well Information

# %%
wellinfo = pd.read_csv('E:\\Snake Valley Water\\Transducer Data\\Database Archive\\well.csv',header=0,index_col=0)

# %% [markdown]
# ### Manual Water Levels

# %%
manualwls = "E:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\All tape measurements.csv"

# %%
manual = pd.read_csv(manualwls, skiprows=0,parse_dates=0,index_col="DateTime",engine="python")

# %%
# this script removes extra fields from a database download of all mamual measurements
try:
    manual = manual.drop(["ReadingID","MeasuredLevel","Temp","BaroEfficiencyLevel","DeltaLevel","DTWBelowCasing",
                          "DriftCorrection","DTWBelowGroundSurface","WaterElevation","Tape","MeasuredByID"],axis=1)
    manual.to_csv("E:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\All tape measurements.csv")
except(ValueError):
    pass

# %% [markdown]
# ### Barometric Pressure Data

# %% [markdown]
# The script below uses a complete file path with wildcard ending to find all of the relevant files in a directory (folder) to generate a Pandas dataframe of all of the compiled data, with duplicates removed and datetimes sorted.

# %%
def compilation(inputfile):
    """
    This function reads multiple Solinst transducer files in a directory and generates a compiled Pandas dataframe.
    
    inputfile = complete file path to input files; use * for wildcard in file name
        example -> 'E:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\all\\LEV\\*baro*' picks any file containing 'baro'
    
    packages required:
        pandas as pd
        glob
        os
        xmltodict
    """
    
    def getfilename(path):
        # this function extracts the file name without file path or extension
        return path.split('\\').pop().split('/').pop().rsplit('.', 1)[0]
    
    # create empty dictionary to hold dataframes
    f={}

    # generate list of relevant files
    filelist = glob.glob(inputfile)

    # iterate through list of relevant files
    for infile in filelist:
        # get the extension of the input file
        filetype = os.path.splitext(infile)[1]
        # run computations using lev files
        if filetype=='.lev':
            # open text file
            with open(infile) as fd:
                # find beginning of data
                indices = fd.readlines().index('[Data]\n')

            # convert data to pandas dataframe starting at the indexed data line
            f[getfilename(infile)] = pd.read_table(infile, parse_dates=True, sep='     ', index_col=0,
                                           skiprows=indices+2, names=['DateTime','Level','Temperature'], skipfooter=1,engine='python')
            # add extension-free file name to dataframe
            f[getfilename(infile)]['name'] = getfilename(infile)
            
        # run computations using xle files
        elif filetype=='.xle':
            # open text file
            with open(infile) as fd:
                # parse xml
                obj = xmltodict.parse(fd.read(),encoding="ISO-8859-1")
            # navigate through xml to the data
            wellrawdata = obj['Body_xle']['Data']['Log']
            # convert xml data to pandas dataframe
            f[getfilename(infile)] = pd.DataFrame(wellrawdata)
            # get header names and apply to the pandas dataframe          
            f[getfilename(infile)][str(obj['Body_xle']['Ch1_data_header']['Identification']).title()] = f[getfilename(infile)]['ch1']
            f[getfilename(infile)][str(obj['Body_xle']['Ch2_data_header']['Identification']).title()] = f[getfilename(infile)]['ch2']
  
            # add extension-free file name to dataframe
            f[getfilename(infile)]['name'] = getfilename(infile)
            # combine Date and Time fields into one field
            f[getfilename(infile)]['DateTime'] = pd.to_datetime(f[getfilename(infile)].apply(lambda x: x['Date'] + ' ' + x['Time'], 1))
            f[getfilename(infile)] = f[getfilename(infile)].reset_index()
            f[getfilename(infile)] = f[getfilename(infile)].set_index('DateTime')
            f[getfilename(infile)] = f[getfilename(infile)].drop(['Date','Time','@id','ch1','ch2','index','ms'],axis=1)
        # run computations using csv files

        else:
            pass
    # concatonate all of the dataframes in dictionary f to one dataframe: g
    g = pd.concat(f)
    # remove multiindex and replace with index=Datetime
    g = g.reset_index()
    g = g.set_index(['DateTime'])
    # drop old indexes
    g = g.drop(['level_0'],axis=1)
    # remove duplicates based on index then sort by index
    g['ind']=g.index
    g.drop_duplicates(subset='ind',inplace=True)
    g.drop('ind',axis=1,inplace=True)
    g = g.sort()
    # ensure that the Level and Temperature data are in a float format
    g['Level'] = g['Level'].convert_objects(convert_numeric=True)
    g['Temperature'] = g['Temperature'].convert_objects(convert_numeric=True)
    outfile = g
    return outfile

# %% [markdown]
# The appendomatic function below appends new data (infile) onto existing data by parsing the new data and making it the same format as the existing data, then merging the datasets, then overwriting the existing data.

# %%
def appendomatic(infile,existingfile):
        
    def getfilename(path):
        # this function extracts the file name without file path or extension
        return path.split('\\').pop().split('/').pop().rsplit('.', 1)[0]

    # get the extension of the input file
    filetype = os.path.splitext(infile)[1]
    
    # run computations using lev files
    if filetype=='.lev':
        # open text file
        with open(infile) as fd:
            # find beginning of data
            indices = fd.readlines().index('[Data]\n')

        # convert data to pandas dataframe starting at the indexed data line
        f = pd.read_table(infile, parse_dates=True, sep='     ', index_col=0,
                                       skiprows=indices+2, names=['DateTime','Level','Temperature'], skipfooter=1,engine='python')
        # add extension-free file name to dataframe
        f['name'] = getfilename(infile)

    # run computations using xle files
    elif filetype=='.xle':
        # open text file
        with open(infile) as fd:
            # parse xml
            obj = xmltodict.parse(fd.read(),encoding="ISO-8859-1")
        # navigate through xml to the data
        wellrawdata = obj['Body_xle']['Data']['Log']
        # convert xml data to pandas dataframe
        f = pd.DataFrame(wellrawdata)
        # get header names and apply to the pandas dataframe
        f[str(obj['Body_xle']['Ch1_data_header']['Identification']).title()] = f['ch1']
        f[str(obj['Body_xle']['Ch2_data_header']['Identification']).title()] = f['ch2']

        # add extension-free file name to dataframe
        f['name'] = getfilename(infile)
        # combine Date and Time fields into one field
        f['DateTime'] = pd.to_datetime(f.apply(lambda x: x['Date'] + ' ' + x['Time'], 1))
        f = f.reset_index()
        f = f.set_index('DateTime')
        f = f.drop(['Date','Time','@id','ch1','ch2','index','ms'],axis=1)
    
    # run computations using csv files
    elif filetype=='.csv':
        with open(infile) as fd:
        # find beginning of data
            try:
                indices = fd.readlines().index('Date,Time,ms,Level,Temperature\n')
            except ValueError:
                indices = fd.readlines().index(',Date,Time,100 ms,Level,Temperature\n')
        f = pd.read_csv(infile, skiprows=indices, skipfooter=1, engine='python')
        # add extension-free file name to dataframe
        f['name'] = getfilename(infile)
        # combine Date and Time fields into one field
        f['DateTime'] = pd.to_datetime(f.apply(lambda x: x['Date'] + ' ' + x['Time'], 1))
        f = f.reset_index()
        f = f.set_index('DateTime')
        f = f.drop(['Date','Time','ms','index'],axis=1)
            # skip other file types
    else:
        pass

    # ensure that the Level and Temperature data are in a float format
    f['Level'] = f['Level'].convert_objects(convert_numeric=True)
    f['Temperature'] = f['Temperature'].convert_objects(convert_numeric=True)
    h = pd.read_csv(existingfile,index_col=0,header=0,parse_dates=True)
    g = pd.concat([h,f])
    # remove duplicates based on index then sort by index
    g['ind']=g.index
    g.drop_duplicates(subset='ind',inplace=True)
    g.drop('ind',axis=1,inplace=True)
    g = g.sort()    
    os.remove(exists)
    g.to_csv(exists)

# %%
def get_transducer_headers(inputfile):
    wellrawinfo = obj['Body_xle']['Instrument_info']
    wellrawinfo2 = obj['Body_xle']['Instrument_info_data_header']
    wellinfo = pd.Series(wellrawinfo)
    wellinfo2 = pd.Series(wellrawinfo2)
    wellinfo = pd.concat([wellinfo,wellinfo2],axis=0)
    wellinfodf = pd.DataFrame(wellinfo).transpose()
    #wellinfodf = wellinfodf.set_index('Location')
    wellinfodf

# %% [markdown]
# #### PW10 Barometric Pressure Data

# %%
pw10baro_files = "E:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\all\\XLE\\pw10 baro*"
pw10baro = compilation(pw10baro_files)
pw10baro['Level'].plot()
plt.title('PW10 Barometric Pressure')
plt.ylabel('Pressure (ft)')

pw10baro.to_csv("E:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\all\\pw10baro.csv")

# %% [markdown]
# #### PW03 Barometric Pressure Data

# %%
pw03baro_files = "E:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\all\\XLE\\pw03 baro*"
pw03baro = compilation(pw03baro_files)
pw03baro['Level'].plot()
plt.title('PW03 Barometric Pressure')
plt.ylabel('Pressure (ft)')

pw03baro.to_csv("E:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\all\\pw03baro.csv")

# %%
exists = "E:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\all\\pw03baro.csv"
append = "E:\\Snake Valley Water\\Transducer Data\\pw03baro 2012-02-29.csv"
appendomatic(append,exists)

# %%
pw03baro = pd.read_csv(exists,index_col=0)
pw03baro['Level'].plot()

# %% [markdown]
# #### PW19 Barometric Pressure Data

# %%
pw19baro_files = "E:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\all\\XLE\\pw19 baro*"
pw19baro = compilation(pw19baro_files)
pw19baro['Level'].plot()
plt.title('PW19 Barometric Pressure')
plt.ylabel('Pressure (ft)')

pw19baro.to_csv("E:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\all\\pw19baro.csv")

# %% [markdown]
# #### Comparison of Barometric Pressure Data

# %%
pw03baro['pw03'] = pw03baro['Level']
pw10baro['pw10'] = pw10baro['Level']
pw19baro['pw19'] = pw19baro['Level']
baro = pd.merge(pw03baro,pw10baro,how="outer",left_index=True,right_index=True)
baro = pd.merge(baro,pw19baro,how="outer",left_index=True,right_index=True)
baro.dropna(axis=0,inplace=True)
baro['integr'] = 0 #for vented transducers

# %% [markdown]
# ##### PW03 and PW10 Comparison

# %%
x03 = baro['pw03']
x10 = baro['pw10']
plt.figure()
plt.scatter(x03,x10)
plt.xlabel('Pressure at PW03 (ft)')
plt.ylabel('Pressure at PW10 (ft)')

x = sm.add_constant(x03)
y = x10

est = sm.OLS(y, x)
est = est.fit()
print est.summary()

x_prime = np.linspace(x03.min(),x03.max(),100)[:, np.newaxis]
x_prime = sm.add_constant(x_prime)
y_hat = est.predict(x_prime)

plt.plot(x_prime[:, 1], y_hat, color='red', alpha=0.9, zorder = 3, linewidth=2.0, label='OLS fit')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   pw10   R-squared:                       0.979
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                 8.330e+05
# Date:                Thu, 12 Mar 2015   Prob (F-statistic):               0.00
# Time:                        14:44:31   Log-Likelihood:                 39996.
# No. Observations:               17470   AIC:                        -7.999e+04
# Df Residuals:                   17468   BIC:                        -7.997e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.4390      0.003    146.361      0.000         0.433     0.445
# pw03           0.9931      0.001    912.688      0.000         0.991     0.995
# ==============================================================================
# Omnibus:                      177.964   Durbin-Watson:                   0.194
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              183.310
# Skew:                           0.251   Prob(JB):                     1.57e-40
# Kurtosis:                       2.989   Cond. No.                         50.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sns.jointplot('pw03','pw10',baro, size=10, kind="reg", color="seagreen")

# %%
sns.jointplot('pw03','pw10', baro,size=10, kind="resid");

# %% [markdown]
# ##### PW03 and PW19 Comparison

# %%
x03 = baro['pw03']
x19 = baro['pw19']
plt.figure()
plt.scatter(x03,x19)
plt.xlabel('Pressure at PW03 (ft)')
plt.ylabel('Pressure at PW19 (ft)')

x = sm.add_constant(x03)
y = x19

est = sm.OLS(y, x)
est = est.fit()
print est.summary()

x_prime = np.linspace(x03.min(),x03.max(),100)[:, np.newaxis]
x_prime = sm.add_constant(x_prime)
y_hat = est.predict(x_prime)

plt.plot(x_prime[:, 1], y_hat, color='red', alpha=0.9, zorder = 3, linewidth=2.0, label='OLS fit')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   pw19   R-squared:                       0.970
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                 5.585e+05
# Date:                Thu, 12 Mar 2015   Prob (F-statistic):               0.00
# Time:                        14:44:38   Log-Likelihood:                 36373.
# No. Observations:               17470   AIC:                        -7.274e+04
# Df Residuals:                   17468   BIC:                        -7.273e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.4539      0.004    122.981      0.000         0.447     0.461
# pw03           1.0005      0.001    747.303      0.000         0.998     1.003
# ==============================================================================
# Omnibus:                      177.930   Durbin-Watson:                   0.166
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              197.783
# Skew:                           0.208   Prob(JB):                     1.13e-43
# Kurtosis:                       3.314   Cond. No.                         50.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sns.jointplot('pw03','pw19',baro, size=10, kind="reg", color="seagreen")

# %%
sns.jointplot('pw03','pw19', baro,size=10, kind="resid");

# %% [markdown]
# ##### PW10 and PW19 Comparison

# %%
x10 = baro['pw10']
x19 = baro['pw19']
plt.figure()
plt.scatter(x10,x19)
plt.xlabel('Pressure at PW10 (ft)')
plt.ylabel('Pressure at PW19 (ft)')

x = sm.add_constant(x10)
y = x19

est = sm.OLS(y, x)
est = est.fit()
print est.summary()

x_prime = np.linspace(x10.min(),x10.max(),100)[:, np.newaxis]
x_prime = sm.add_constant(x_prime)
y_hat = est.predict(x_prime)

plt.plot(x_prime[:, 1], y_hat, color='red', alpha=0.9, zorder = 3, linewidth=2.0, label='OLS fit')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   pw19   R-squared:                       0.974
# Model:                            OLS   Adj. R-squared:                  0.974
# Method:                 Least Squares   F-statistic:                 6.507e+05
# Date:                Thu, 12 Mar 2015   Prob (F-statistic):               0.00
# Time:                        14:44:43   Log-Likelihood:                 37671.
# No. Observations:               17470   AIC:                        -7.534e+04
# Df Residuals:                   17468   BIC:                        -7.532e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.0378      0.004      9.597      0.000         0.030     0.045
# pw10           0.9992      0.001    806.683      0.000         0.997     1.002
# ==============================================================================
# Omnibus:                      163.433   Durbin-Watson:                   0.113
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              128.358
# Skew:                           0.130   Prob(JB):                     1.34e-28
# Kurtosis:                       2.670   Cond. No.                         64.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sns.jointplot('pw10','pw19',baro, size=10, kind="reg", color="seagreen")

# %%
sns.jointplot('pw03','pw19', baro,size=10, kind="resid");
plt.xlabel('PW03 feet of pressure')
plt.xlabel('PW19 feet of pressure')

# %% [markdown]
# ## Water Level Tranducer Data

# %% [markdown]
# ### Import Data

# %%
infile = "E:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\2015\\2015 q1\\pw01a 2015-03-03.xle"

def getfilename(path):
    # this function extracts the file name without file path or extension
    return path.split('\\').pop().split('/').pop().rsplit('.', 1)[0]

wellid = wellinfo[wellinfo['Well']==getfilename(infile)[0:5].strip().upper()].index.values[0]

# open text file
with open(infile) as fd:
    # parse xml
    obj = xmltodict.parse(fd.read(),encoding="ISO-8859-1")
# navigate through xml to the data
wellrawdata = obj['Body_xle']['Data']['Log']
# convert xml data to pandas dataframe
f = pd.DataFrame(wellrawdata)
# get header names and apply to the pandas dataframe
f[str(obj['Body_xle']['Ch1_data_header']['Identification']).title()] = f['ch1']
f[str(obj['Body_xle']['Ch2_data_header']['Identification']).title()] = f['ch2']
# add extension-free file name to dataframe
f['name'] = getfilename(infile)
# combine Date and Time fields into one field
f['DateTime'] = pd.to_datetime(f.apply(lambda x: x['Date'] + ' ' + x['Time'], 1))
f[str(obj['Body_xle']['Ch1_data_header']['Identification']).title()] = f[str(obj['Body_xle']['Ch1_data_header']['Identification']).title()].convert_objects(convert_numeric=True)
f[str(obj['Body_xle']['Ch2_data_header']['Identification']).title()] = f[str(obj['Body_xle']['Ch2_data_header']['Identification']).title()].convert_objects(convert_numeric=True)
f = f.reset_index()
f = f.set_index('DateTime')
f = f.drop(['Date','Time','@id','ch1','ch2','index','ms'],axis=1)

# %% [markdown]
# ### Match Barometric Data

# %%
del(g)

# %%
barologtype ={1:'integr',2:'pw03',3:'pw10',4:'pw19',5:'pw25',6:'twin',7:'courthouse'}
bse = f.index.to_datetime().minute[0]
btype = int(wellinfo[wellinfo.index==wellid]['BaroLoggerTypeID'])
b = baro[barologtype.get(btype)]
b = b.resample('1Min', how='mean')
b = b.interpolate(method='time')
b = b.resample('60Min', how='mean', base=bse)
b = b.to_frame()

# %%
g = pd.merge(f,b,left_index=True,right_index=True,how='inner')
g.columns
# Out:
# Index([u'Level', u'Temperature', u'name', u'pw03'], dtype='object')

# %%
g['wtr_abv']=g['Level']-g[barologtype.get(btype)]
g['wtr_abv'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Get Barometric Efficiency

# %%
be = wellinfo[wellinfo.index==wellid]['BaroEfficiency']
be = be.iloc[0]
g['be_corrected']=g['wtr_abv'] + be*g['wtr_abv']

# %%
g['bedeltalevel'] = g['be_corrected']-g['be_corrected'][0]

# %% [markdown]
# ### Remove Drift

# %% [markdown]
# http://stackoverflow.com/questions/9877391/how-to-get-the-closest-single-row-after-a-specific-datetime-index-using-python-p
# http://stackoverflow.com/questions/15115547/find-closest-row-of-dataframe-to-given-time-in-pandas

# %%
print max(f.index.to_datetime())
print min(f.index.to_datetime())
# Out:
# 2015-03-03 11:00:00
# 2014-12-09 12:00:00

# %%
def fcl(df, dtObj):
    '''
    df = dataframe
    dtObj = date object
    '''
    return df.iloc[np.argmin(np.abs(df.index.to_pydatetime() - dtObj))]

# %%
g['measureddtw']=fcl(manual[manual['WellID']== wellid],min(g.index.to_datetime()))[1]-g['bedeltalevel']
lastdtw = g['measureddtw'][-1]
lastdtw
# Out:
# 102.02608083333334

# %%
last = fcl(manual[manual['WellID']== wellid],max(g.index.to_datetime()))[1]
first = fcl(manual[manual['WellID']== wellid],min(g.index.to_datetime()))[1]
print g[g.index.to_datetime()==max(g.index.to_datetime())]
print last
print first
# Out:
#                       Level  Temperature              name      pw03  \
# 2015-03-03 11:00:00  8.4987       11.321  pw01a 2015-03-03  2.501128
#
#                       wtr_abv  be_corrected  bedeltalevel
# 2015-03-03 11:00:00  5.997572      5.997572      0.563919
# 101.97
# 102.59
