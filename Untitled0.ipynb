# %%
import oct2py
# %load_ext octavemagic
# Out:
# ---------------------------------------------------------------------------
# Oct2PyError                               Traceback (most recent call last)
# <ipython-input-3-dec1803374ec> in <module>()
#       1 import oct2py
# ----> 2 get_ipython().magic(u'load_ext octavemagic')
#
# C:\Python27\ArcGIS10.2\Lib\site-packages\IPython\core\interactiveshell.pyc in magic(self, arg_s)
#    2203         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2204         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2205         return self.run_line_magic(magic_name, magic_arg_s)
#    2206
#    2207     #-------------------------------------------------------------------------
#
# C:\Python27\ArcGIS10.2\Lib\site-packages\IPython\core\interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2124                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2125             with self.builtin_trap:
# -> 2126                 result = fn(*args,**kwargs)
# ...
