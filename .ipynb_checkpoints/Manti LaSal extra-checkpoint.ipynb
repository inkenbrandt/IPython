# %% [markdown]
# http://earthpy.org/time_series_analysis_with_pandas_part_2.html

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import scipy.stats as sp
import statsmodels.api as sm
import ulmo
from pandas.stats.api import ols
from datetime import datetime
from pylab import rcParams
rcParams['figure.figsize'] = 15, 10

# %%
from IPython.html.widgets import interact

# %%
def importusgssite(siteno,sitename):
    sitename = {}
    sitename = ulmo.usgs.nwis.get_site_data(siteno, service="daily", period="all")
    sitename = pd.DataFrame(sitename['00060:00003']['values'])
    sitename['dates'] = pd.to_datetime(pd.Series(sitename['datetime']))
    sitename.set_index(['dates'],inplace=True)
    sitename = sitename.drop(['datetime'],axis=1)
    sitename['value'] = sitename['value'].astype(float)
    sitename = sitename.replace('-999999',np.NAN)
    sitename['mon']=sitename.index.month
    return sitename

# %%
Muddy_Creek = importusgssite("09330500","Muddy_Creek")
Salina_Creek = importusgssite("10205030","Salina_Creek")
Ferron_Creek = importusgssite("09326500","Ferron_Creek")
Manti_Creek = importusgssite("10215900","Manti_Creek")
# Out:
# INFO:ulmo.usgs.nwis.core:processing data from request: http://waterservices.usgs.gov/nwis/dv/?startDT=1851-01-01&site=09330500&format=waterml
# INFO:ulmo.usgs.nwis.core:processing data from request: http://waterservices.usgs.gov/nwis/dv/?startDT=1851-01-01&site=10205030&format=waterml
# INFO:ulmo.usgs.nwis.core:processing data from request: http://waterservices.usgs.gov/nwis/dv/?startDT=1851-01-01&site=09326500&format=waterml
# INFO:ulmo.usgs.nwis.core:processing data from request: http://waterservices.usgs.gov/nwis/dv/?startDT=1851-01-01&site=10215900&format=waterml

# %%
def boxandscatter(station, yr=1930):
    station = eval(station)
    station.boxplot(column=['value'], by='mon')
    dfmon = station.resample('M',how='mean')
    plt.scatter(dfmon['mon'][dfmon.index.year==yr], dfmon['value'][dfmon.index.year==yr], c='purple')
    plt.ylim(0.01,10000)
    plt.ylabel('discharge (cfs)')
    plt.xlabel('month')
    plt.yscale('log')

# %%
stations = ['Muddy_Creek','Salina_Creek','Ferron_Creek','Manti_Creek']

# %%
cd = interact(boxandscatter, station=stations, yr=(1990, 2015, 1))

# %%
def kp(station, wind=1):
    station = eval(station)
    pd.rolling_mean(station['value'], window=wind, center=True).plot(ylim=(0.01,1000),xlim=('1/1/1950','1/1/2015'))
    plt.yscale('log')

# %%
cc = interact(kp, station=stations, wind=(1,1000,100))

# %%
Muddy_Creek_monthly = Muddy_Creek.resample('M', how='mean')
Muddy_Creek_monthly['baseflow'] = pd.rolling_min(Muddy_Creek_monthly['value'],window=11,center=True)

# %%
Salina_Creek['baseflow'] = pd.rolling_min(Salina_Creek['value'],window=250,center=True)

# %%
print(Muddy_Creek_mo_group)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b614f7e76a83> in <module>()
# ----> 1 print(Muddy_Creek_mo_group)
#
# NameError: name 'Muddy_Creek_mo_group' is not defined

# %%
data = Muddy_Creek['value'][np.isfinite(Muddy_Creek['value'])]
data
# Out:
# dates
# 1910-10-01     18
# 1910-10-02     18
# 1910-10-03     18
# 1910-10-04     18
# 1910-10-05     18
# 1910-10-06     18
# 1910-10-07     18
# 1910-10-08     18
# 1910-10-09     18
# 1910-10-10     18
# 1910-10-11     18
# 1910-10-12     18
# 1910-10-13     18
# 1910-10-14     18
# 1910-10-15    265
# ...
# 2014-11-02    12.0
# 2014-11-03    11.0
# 2014-11-04     9.4
# 2014-11-05    12.0
# 2014-11-06    11.0
# 2014-11-07    11.0
# 2014-11-08    11.0
# 2014-11-09    11.0
# 2014-11-10    11.0
# 2014-11-11    11.0
# 2014-11-12    15.0
# 2014-11-13    16.0
# 2014-11-14    17.0
# 2014-11-15    17.0
# 2014-11-16    15.0
# Name: value, Length: 25096

# %% [markdown]
# http://stackoverflow.com/questions/15408371/cumulative-distribution-plots-python
# http://hydroclimpy.sourceforge.net/installation.html

# %%
values, base = np.histogram(data, bins=40)
#evaluate the cumulative
cumulative = np.cumsum(values)
x = [(base[:-1][i]-base[:-1])/len(base[:-1]) for i in range(len(base[:-1]))]
# plot the cumulative function
plt.plot(x, cumulative, c='blue')
# Out:
# [<matplotlib.lines.Line2D at 0x11c51590>,
#  <matplotlib.lines.Line2D at 0x11c51710>,
#  <matplotlib.lines.Line2D at 0x11c516f0>,
#  <matplotlib.lines.Line2D at 0x11c51830>,
#  <matplotlib.lines.Line2D at 0x11c51910>,
#  <matplotlib.lines.Line2D at 0x11c519f0>,
#  <matplotlib.lines.Line2D at 0x11c51ad0>,
#  <matplotlib.lines.Line2D at 0x11d7ded0>,
#  <matplotlib.lines.Line2D at 0x11c51c90>,
#  <matplotlib.lines.Line2D at 0x11c51d70>,
#  <matplotlib.lines.Line2D at 0x11c51e50>,
#  <matplotlib.lines.Line2D at 0x11c51f30>,
#  <matplotlib.lines.Line2D at 0x11c39030>,
#  <matplotlib.lines.Line2D at 0x11c39110>,
#  <matplotlib.lines.Line2D at 0x11c51bb0>,
#  <matplotlib.lines.Line2D at 0x11c392d0>,
#  <matplotlib.lines.Line2D at 0x11c393b0>,
#  <matplotlib.lines.Line2D at 0x11c39490>,
#  <matplotlib.lines.Line2D at 0x11c39570>,
#  <matplotlib.lines.Line2D at 0x11c39650>,
#  <matplotlib.lines.Line2D at 0x11c39730>,
#  <matplotlib.lines.Line2D at 0x11c391f0>,
#  <matplotlib.lines.Line2D at 0x11c398f0>,
#  <matplotlib.lines.Line2D at 0x11c399d0>,
#  <matplotlib.lines.Line2D at 0x11c39ab0>,
#  <matplotlib.lines.Line2D at 0x11c39b90>,
#  <matplotlib.lines.Line2D at 0x11c39c70>,
#  <matplotlib.lines.Line2D at 0x11c39d50>,
#  <matplotlib.lines.Line2D at 0x11c39810>,
#  <matplotlib.lines.Line2D at 0x11c39f10>,
#  <matplotlib.lines.Line2D at 0x11c39ff0>,
#  <matplotlib.lines.Line2D at 0x11c460f0>,
#  <matplotlib.lines.Line2D at 0x11c461d0>,
#  <matplotlib.lines.Line2D at 0x11c462b0>,
#  <matplotlib.lines.Line2D at 0x11c46390>,
#  <matplotlib.lines.Line2D at 0x11c39e30>,
#  <matplotlib.lines.Line2D at 0x11c46550>,
#  <matplotlib.lines.Line2D at 0x11c46630>,
#  <matplotlib.lines.Line2D at 0x11c46710>,
#  <matplotlib.lines.Line2D at 0x11c467f0>]
