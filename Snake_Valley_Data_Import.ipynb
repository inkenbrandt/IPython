# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import os
import glob
import xmltodict
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import matplotlib.ticker as tick
import scipy.stats as sp
import statsmodels.api as sm
from pandas.stats.api import ols
from datetime import datetime
from pylab import rcParams
rcParams['figure.figsize'] = 15, 10

# %% [markdown]
# ## Import Relevant Data

# %% [markdown]
# ### Manual Water Levels

# %%
manualwls = "E:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\All tape measurements.csv"

# %%
manual = pd.read_csv(manualwls, skiprows=0,parse_dates=0,index_col="DateTime",engine="python")

# %%
# this script removes extra fields from a database download of all mamual measurements
try:
    manual = manual.drop(["ReadingID","MeasuredLevel","Temp","BaroEfficiencyLevel","DeltaLevel","DTWBelowCasing",
                          "DriftCorrection","DTWBelowGroundSurface","WaterElevation","Tape","MeasuredByID"],axis=1)
    manual.to_csv("E:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\All tape measurements.csv")
except(ValueError):
    pass

# %%
manual
# Out:
#                      WellID  MeasuredDTW
# DateTime
# 2007-08-23 11:30:00       1        94.24
# 2007-08-30 13:26:00       1        93.55
# 2007-09-22 12:00:00       1        93.10
# 2007-09-27 12:00:00       1        93.72
# 2007-10-23 12:00:00       1        93.45
# 2007-11-14 07:53:00       1        93.29
# 2008-02-28 10:36:00       1        93.00
# 2008-04-30 09:25:00       1        92.87
# 2008-07-28 17:38:00       1        94.68
# 2008-10-28 15:45:00       1        97.38
# 2009-02-09 17:05:00       1        96.41
# 2009-06-01 18:31:00       1        98.08
# 2009-09-14 18:54:00       1        99.45
# 2009-12-01 17:35:00       1        98.46
# 2010-03-04 10:34:00       1        99.20
# 2010-06-08 10:11:00       1        99.70
# 2010-09-14 10:42:00       1       100.32
# 2010-12-07 10:03:00       1        99.81
# 2011-03-01 15:20:00       1        99.25
# 2011-06-07 09:30:00       1        97.63
# 2011-09-13 09:31:00       1        95.41
# 2011-12-06 10:53:00       1        95.35
# ...

# %% [markdown]
# ### Barometric Pressure Data

# %% [markdown]
# The file below

# %%
levfile = "E:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\all\\LEV\\pw10baro*.lev"
f={}
filelist = glob.glob(levfile)
filename = []

def getfilename(path):
    return path.split('\\').pop().split('/').pop().rsplit('.', 1)[0]

for levfile in filelist:
    with open(levfile) as inputfile:
        indices = inputfile.readlines().index('[Data]\n')

    f[getfilename(levfile)] = pd.read_table(levfile, parse_dates=True, sep="     ", index_col=0,
                                   skiprows=indices+2, names=["DateTime","Level","Temperature"], skipfooter=1,engine="python")
    f[getfilename(levfile)]['name'] = getfilename(levfile)
    filename.append(getfilename(levfile))

g = pd.concat(f)
g = g.reset_index()
g = g.set_index('DateTime')
pw10baro = g.drop('level_0',axis=1)
pw10baro.to_csv("E:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\all\\pw10baro.csv")

# %%
levfile = "E:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\all\\LEV\\pw10baro*.lev"
xlefile = 'E:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\all\\XLE\\pw10 baro*.xle'

wellrawdf={}
filelist = glob.glob(xlefile)
filename = []

def getfilename(path):
    return path.split('\\').pop().split('/').pop().rsplit('.', 1)[0]

for xle in filelist:
  
    with open(xle) as fd:
        obj = xmltodict.parse(fd.read())

    wellrawdata = obj['Body_xle']['Data']['Log']
    wellrawdf[getfilename(xle)] = pd.DataFrame(wellrawdata).set_index(['Date','Time'])
    wellrawdf[getfilename(xle)][obj['Body_xle']['Ch1_data_header']['Identification']] = wellrawdf[getfilename(xle)]['ch1']
    wellrawdf[getfilename(xle)][obj['Body_xle']['Ch2_data_header']['Identification']] = wellrawdf[getfilename(xle)]['ch2']
    wellrawdf[getfilename(xle)] = wellrawdf[getfilename(xle)].drop(['ms','@id','ch1','ch2'],axis=1)
    wellrawdf[getfilename(xle)]['name'] = getfilename(xle)
  
h = pd.concat(wellrawdf)
h = h.reset_index()
h['DateTime'] = pd.to_datetime(h.apply(lambda x: x['Date'] + ' ' + x['Time'], 1))
h = h.set_index(['DateTime'])

pw10baro1 = h.drop(['level_0','Date', 'Time'],axis=1)
pw10baro1
# Out:
#                       Level Temperature                  name
# DateTime
# 2011-12-07 13:53:59  3.3944      16.329  pw10 baro 2012-06-06
# 2011-12-07 14:53:59  3.3415      20.487  pw10 baro 2012-06-06
# 2011-12-07 15:53:59  3.3287      20.071  pw10 baro 2012-06-06
# 2011-12-07 16:53:59  3.3223      15.032  pw10 baro 2012-06-06
# 2011-12-07 17:53:59  3.2840       0.669  pw10 baro 2012-06-06
# 2011-12-07 18:53:59  3.2617      -5.720  pw10 baro 2012-06-06
# 2011-12-07 19:53:59  3.2480      -7.709  pw10 baro 2012-06-06
# 2011-12-07 20:53:59  3.2444      -8.430  pw10 baro 2012-06-06
# 2011-12-07 21:53:59  3.2357      -8.665  pw10 baro 2012-06-06
# 2011-12-07 22:53:59  3.2307      -9.190  pw10 baro 2012-06-06
# 2011-12-07 23:53:59  3.2254      -9.455  pw10 baro 2012-06-06
# 2011-12-08 00:53:59  3.2173      -8.841  pw10 baro 2012-06-06
# 2011-12-08 01:53:59  3.2088      -8.879  pw10 baro 2012-06-06
# 2011-12-08 02:53:59  3.2073      -9.083  pw10 baro 2012-06-06
# ...

# %%
wellrawinfo = obj['Body_xle']['Instrument_info']
wellrawinfo2 = obj['Body_xle']['Instrument_info_data_header']
wellinfo = pd.Series(wellrawinfo)
wellinfo2 = pd.Series(wellrawinfo2)
wellinfo = pd.concat([wellinfo,wellinfo2],axis=0)
wellinfodf = pd.DataFrame(wellinfo).transpose()
#wellinfodf = wellinfodf.set_index('Location')
wellinfodf
# Out:
#   Instrument_type Model_number Instrument_state Serial_number Battery_level  \
# 0         LT_Gold           M5          Stopped       1020752           100
#
#   Channel Firmware        Project_ID Location Latitude Longtitude Sample_rate  \
# 0       2    2.007  UGS Snake Valley    PW06b   43.000     79.000      360000
#
#   Sample_mode Event_ch Event_threshold Schedule           Start_time  \
# 0           0        1        0.000000     None  2014/03/04 13:00:00
#
#              Stop_time Num_log
# 0  2014/03/04 12:36:50    2183

# %%
g = pd.concat(f)
g = g.reset_index()
g = g.set_index('DateTime')
pw10baro = g.drop('level_0',axis=1)
pw10baro.to_csv("E:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\all\\pw10baro.csv")
#writer = pd.ExcelWriter("O:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\all\\baro.xlsx", engine='xlsxwriter')
#pw10baro.to_excel(writer,'pw10')
#writer.save()

# %%
d = {}
d[filename[0]] = f[filename[0]]
for i in range(len(filename)-1):
    d[filename[i+1]] = pd.merge(f[filename[i+1]], d[filename[i]], left_index=True, right_index=True, how='outer')
d
# Out:
# {('p',
#   ''):                       LEVEL  TEMPERATURE  LEVEL_x  TEMPERATURE_x  LEVEL_y  \
#  DateTime
#  2011-06-08 13:21:04  3.0484       30.366   3.0484         30.366   3.0484
#  2011-06-08 14:21:04  3.0148       31.310   3.0148         31.310   3.0148
#  2011-06-08 15:21:04  3.0161       29.001   3.0161         29.001   3.0161
#  2011-06-08 16:21:04  3.0106       33.041   3.0106         33.041   3.0106
#  2011-06-08 17:21:04  3.0282       33.411   3.0282         33.411   3.0282
#  2011-06-08 18:21:04  3.0565       22.344   3.0565         22.344   3.0565
#  2011-06-08 19:21:04  3.0836       20.420   3.0836         20.420   3.0836
#  2011-06-08 20:21:04  3.0957       17.552   3.0957         17.552   3.0957
#  2011-06-08 21:21:04  3.1095       14.993   3.1095         14.993   3.1095
#  2011-06-08 22:21:04  3.1175       14.851   3.1175         14.851   3.1175
#  2011-06-08 23:21:04  3.1314       14.654   3.1314         14.654   3.1314
# ...

# %%
f = {}
f[sites[0]] = d[sites[0]]
for i in range(len(sites)-1):
    f[sites[i+1]] = pd.merge(d[sites[i+1]], f[sites[i]], left_index=True, right_index=True, how='outer')
