# %% [markdown]
# # Mann-Kendall Test for Trend

# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import urllib2
from scipy.stats import norm

# %%
def mk_test(x, alpha = 0.05):
    """
    this perform the MK (Mann-Kendall) test to check if there is any trend present in 
    data or not
    
    Input:
        x:   a vector of data
        alpha: significance level
    
    Output:
        trend: tells the trend (increasing, decreasing or no trend)
        h: True (if trend is present) or False (if trend is absence)
        p: p value of the sifnificance test
        z: normalized test statistics 
        
    Examples
    --------
      >>> x = np.random.rand(100)
      >>> trend,h,p,z = mk_test(x,0.05) 
      
    Credit: http://pydoc.net/Python/ambhas/0.4.0/ambhas.stats/
    """
    n = len(x)
    
    # calculate S 
    s = 0
    for k in xrange(n-1):
        for j in xrange(k+1,n):
            s += np.sign(x[j] - x[k])
    
    # calculate the unique data
    unique_x = np.unique(x)
    g = len(unique_x)
    
    # calculate the var(s)
    if n == g: # there is no tie
        var_s = (n*(n-1)*(2*n+5))/18
    else: # there are some ties in data
        tp = np.zeros(unique_x.shape)
        for i in xrange(len(unique_x)):
            tp[i] = sum(unique_x[i] == x)
        var_s = (n*(n-1)*(2*n+5) - np.sum(tp*(tp-1)*(2*tp+5)))/18
    
    if s>0:
        z = (s - 1)/np.sqrt(var_s)
    elif s == 0:
        z = 0
    elif s<0:
        z = (s + 1)/np.sqrt(var_s)
    else:
        z = 0
    
    # calculate the p_value
    p = 2*(1-norm.cdf(abs(z))) # two tail test
    h = abs(z) > norm.ppf(1-alpha/2) 
    
    if (z<0) and h:
        trend = 'decreasing'
    elif (z>0) and h:
        trend = 'increasing'
    else:
        trend = 'no trend'
        
    return pd.Series({'trend':trend, 'varS':round(var_s,3), 'p':round(p,3), 'z':round(z,3), 's':round(s,3)})

# %%
infile= r'http://nwis.waterdata.usgs.gov/usa/nwis/qwdata/?site_no=11530500&agency_cd=USGS&inventory_output=0&rdb_inventory_output=file&TZoutput=0&pm_cd_compare=Greater%20than&radio_parm_cds=parm_cd_list&radio_multiple_parm_cds=00665&qw_attributes=0&format=rdb&qw_sample_wide=wide&rdb_qw_attributes=0&date_format=YYYY-MM-DD&rdb_compression=value&submitted_form=brief_list'
response = urllib2.urlopen(infile)
cols = ['datetime','agency','site','end_dt','end_tm','dtm','dtm_cd','coll_ent_cd','medium_cd','tu_id','body_part_id','PO4']

usgsP = pd.read_table(response, skiprows=65, skip_footer=5, na_values=('-','','No Data','No data'),parse_dates={'datetime':[2,3]})#, parse_cols=cols)
usgsP.columns = cols

usgsP.set_index('datetime',inplace=True)
usgsP.drop(['agency','site','end_dt','end_tm','dtm','dtm_cd','coll_ent_cd','medium_cd','tu_id','body_part_id'],axis=1,inplace=True)
usgsP['month'] = usgsP.index.to_datetime().month.astype(int)
usgsP['year'] = usgsP.index.to_datetime().year.astype(int)
usgsP = usgsP[(usgsP['year']>=1972) & (usgsP.index.to_datetime() <= pd.datetime(1979,10,31))]
usgsP.sort_index(axis=0, inplace=True)

usgsP.sort(columns=['month','year'],axis=0, inplace=True)
usgsP.dropna(inplace=True)

# %%
infile= r'http://nwis.waterdata.usgs.gov/usa/nwis/qwdata/?site_no=11530500&agency_cd=USGS&inventory_output=0&rdb_inventory_output=file&TZoutput=0&pm_cd_compare=Greater%20than&radio_parm_cds=parm_cd_list&radio_multiple_parm_cds=00665&qw_attributes=0&format=rdb&qw_sample_wide=wide&rdb_qw_attributes=0&date_format=YYYY-MM-DD&rdb_compression=value&submitted_form=brief_list'
response = urllib2.urlopen(infile)
cols = ['datetime','agency','site','end_dt','end_tm','dtm','dtm_cd','coll_ent_cd','medium_cd','tu_id','body_part_id','PO4']

usgs = pd.read_table(response, skiprows=65, skip_footer=5, na_values=('-','','No Data','No data','< 0.01','E 0.03','E 0.05','E 0.02'),parse_dates={'datetime':[2,3]})#, parse_cols=cols)
usgs.columns = cols

usgs.set_index('datetime',inplace=True)
usgs.drop(['agency','site','end_dt','end_tm','dtm','dtm_cd','coll_ent_cd','medium_cd','tu_id','body_part_id'],axis=1,inplace=True)
usgs['month'] = usgs.index.to_datetime().month.astype(int)
usgs['year'] = usgs.index.to_datetime().year.astype(int)
usgs = usgs[(usgs['year']>=1972) & (usgs['year']<=1980)]
usgs.sort_index(axis=0, inplace=True)

usgs.sort(columns=['month','year'],axis=0, inplace=True)
usgs.dropna(inplace=True)

usgsGrp = usgs.groupby(['month']).apply(lambda x: st.kendalltau(x['year'], x['PO4'],initial_lexsort=False)).to_frame()
usgsGrp.reset_index(inplace=True)
usgsGrp['p'] = usgsGrp.iloc[:,1].apply(lambda x: x[1],1)
usgsGrp['tau'] = usgsGrp.iloc[:,1].apply(lambda x: x[0],1)
usgsGrp.drop([0],axis=1,inplace=True)
print usgsGrp['tau'].sum()
print norm.pdf(usgsGrp['tau'].sum(),usgsGrp['tau'].mean(),usgsGrp['tau'].std())
print usgsGrp
# Out:
# -3.30690838257
# 2.60125434737e-31
#     month         p       tau
# 0       1  0.915792  0.028172
# 1       2  0.697334 -0.138013
# 2       3  0.012334 -0.666737
# 3       4  0.016134 -0.597741
# 4       5  0.658253 -0.117851
# 5       6  0.109745 -0.507093
# 6       7  0.494908 -0.197028
# 7       8  0.445910  0.203091
# 8       9  0.238647 -0.340168
# 9      10  0.416147 -0.216645
# 10     11  0.243305 -0.414039
# 11     12  0.198153 -0.342857

# %%
infile2 = r'http://pubs.usgs.gov/sir/2012/5049/support/SIR2012_5049_Appendix_2_04022012.xlsx'
response2 = urllib2.urlopen(infile2)
cols = ['site','unit','network','date','time','Nrem','N','Clrem','Cl','TDSrem', 'TDS']
usgsT = pd.read_excel(response2, skiprows=1, skip_footer=5, na_values=('-','','No Data','No data','.'))#, parse_cols=cols)
usgsT.columns = cols
usgsT['strTime'] = usgsT['time'].apply(lambda x: '0000' if np.isnan(x)==True else str(str(int(x)).zfill(4)))
usgsT['strdate'] = usgsT['date'].apply(lambda x: str(x)[:10])
usgsT['datetime'] = pd.to_datetime(usgsT['strdate'] + usgsT['strTime'], format='%Y-%m-%d%H%M', coerce=True)
usgsT.drop(['strTime','strdate'],axis=1,inplace=True)
usgsT.reset_index(inplace=True)
usgsT.set_index('datetime',inplace=True)
usgsT.sort_index(axis=0, inplace=True)
usgsT['year'] = usgsT.index.to_datetime().year.astype(int)
usgsT.sort(columns=['network', 'site', 'year'],axis=0, inplace=True)

# %% [markdown]
# My code

# %%
infile= r'http://nwis.waterdata.usgs.gov/usa/nwis/qwdata/?site_no=11530500&agency_cd=USGS&inventory_output=0&rdb_inventory_output=file&TZoutput=0&pm_cd_compare=Greater%20than&radio_parm_cds=parm_cd_list&radio_multiple_parm_cds=00665&qw_attributes=0&format=rdb&qw_sample_wide=wide&rdb_qw_attributes=0&date_format=YYYY-MM-DD&rdb_compression=value&submitted_form=brief_list'
response = urllib2.urlopen(infile)
cols = ['datetime','agency','site','end_dt','end_tm','dtm','dtm_cd','coll_ent_cd','medium_cd','tu_id','body_part_id','PO4']

usgsP = pd.read_table(response, skiprows=65, skip_footer=5, na_values=('-','','No Data','No data'),parse_dates={'datetime':[2,3]})#, parse_cols=cols)
usgsP.columns = cols

usgsP.set_index('datetime',inplace=True)
usgsP.drop(['agency','site','end_dt','end_tm','dtm','dtm_cd','coll_ent_cd','medium_cd','tu_id','body_part_id'],axis=1,inplace=True)
usgsP['month'] = usgsP.index.to_datetime().month.astype(int)
usgsP['year'] = usgsP.index.to_datetime().year.astype(int)
usgsP = usgsP[(usgsP['year']>=1972) & (usgsP.index.to_datetime() <= pd.datetime(1979,10,31))]
usgsP.sort_index(axis=0, inplace=True)

usgsP.sort(columns=['month','year'],axis=0, inplace=True)
usgsP.dropna(inplace=True)


df = usgsP
const = 'PO4'
region = 'month'

df[const] = df[const].map(lambda x: x.strip('><E '))
df[const] = df[const].astype(float)

df.reset_index(inplace=True)

def ties(x):
    if x >0:
        x = x+1
        return (x)*(x-1)*(x*2+5)
    else:
        return 0.0

def zcalc(Sp, Varp):
    if Sp > 0:
        return (Sp - 1)/Varp**0.5
    elif Sp < 0:
        return (Sp + 1)/Varp**0.5
    else:
        return 0    

g = 0
k, tau,combo = [], [], []
for k, v in df.groupby('month'):
    for i in range(g,len(v.ix[:,const])-1+g):
        v.ix[i,'c'] = np.count_nonzero((v.ix[i:,const].values > v.ix[i,const])) 
        v.ix[i,'d'] = np.count_nonzero((v.ix[i:,const].values < v.ix[i,const]))
        v.ix[i,'t'] = len(v) - v.ix[i,'c'] - v.ix[i,'d'] - i - 1 + g

    g = len(v.ix[:,const])+g
    v.ix[:,'sC'] = v.ix[:,'c'].cumsum()
    v.ix[:,'sD'] = v.ix[:,'d'].cumsum()
    v.ix[:,'S'] = (v.ix[:,'sC'] - v.ix[:,'sD'])
    v.ix[:,'count'] = (v.ix[:,'sC'] + v.ix[:,'sD'])
    v.ix[:,'tau'] = (v.ix[:,'S'])/(v.ix[:,'count'])
    
    v.ix[:,'sT'] = v.ix[:,'t'].apply(lambda x: ties(x)).cumsum()
    v.ix[:,'n'] = len(v)
    v.ix[:,'VarS'] = (len(v)*(len(v)-1)*(len(v)*2+5)-(v.ix[:,'sT']))/18.0
    v.ix[:,'z'] = v.apply(lambda x: zcalc(x['S'],x['VarS']),1) 
    v.ix[:,'prob'] = norm.pdf(v.ix[:,'z'])
    #v.ix[:,'taub'] = (v.ix[:,'sC'] - v.ix[:,'sD'])/np.sqrt(v.ix[:,'count']*(v.ix[:,'count']-v.ix[:,'sT']))
    
    v.dropna(inplace=True)
    b = v.tail(1)
    combo.append(b)

combo = pd.concat(combo)
Sp = combo.S.sum()
Varp = combo.VarS.sum()
total = combo.n.sum()



Z = zcalc(Sp, Varp)
print norm.pdf(Z), Sp, Varp
print combo
# Out:
# 0.000579985509824 -87.0 566.0
#               datetime   PO4  month  year  c  d  t  sC  sD   S  count  \
# 6  1978-01-25 16:45:00  0.14      1  1978  0  1  0  12  15  -3     27
# 11 1978-02-16 14:00:00  0.11      2  1978  0  1  0   2   7  -5      9
# 19 1978-03-21 13:00:00  0.02      3  1978  0  0  1   2  25 -23     27
# 28 1978-04-28 13:45:00  0.06      4  1978  0  1  0   6  29 -23     35
# 36 1978-05-25 14:00:00  0.03      5  1978  0  0  1   8  16  -8     24
# 42 1978-06-27 16:30:00  0.03      6  1978  0  1  0   3   8  -5     11
# 49 1978-07-26 13:00:00  0.02      7  1978  1  0  0   7  10  -3     17
# 57 1978-08-23 14:00:00  0.06      8  1978  0  1  0  14  12   2     26
# 64 1978-09-25 16:00:00  0.05      9  1978  1  0  0   4  15 -11     19
# 72 1978-10-25 15:15:00  0.10     10  1978  1  0  0  10  12  -2     22
# 76 1977-11-22 15:45:00  0.47     11  1977  0  1  0   3   2   1      5
# 83 1977-12-29 15:00:00  0.30     12  1977  0  1  0   7  14  -7     21
#
#          tau   sT  n       VarS         z      prob
# 6  -0.111111   18  8  64.333333 -0.249351  0.386731
# 11 -0.555556   18  5  15.666667 -1.010582  0.239410
# 19 -0.851852   18  8  64.333333 -2.742866  0.009273
# 28 -0.657143   18  9  91.000000 -2.306227  0.027924
# 36 -0.333333  102  8  59.666667 -0.906217  0.264595
# 42 -0.454545  102  6  22.666667 -0.840168  0.280304
# 49 -0.176471  102  7  38.666667 -0.321634  0.378832
# 57  0.076923   36  8  63.333333  0.125656  0.395805
# 64 -0.578947   36  7  42.333333 -1.536947  0.122451
# 72 -0.090909  240  8  52.000000 -0.138675  0.395125
# 76  0.200000   18  4   7.666667  0.000000  0.398942
# 83 -0.333333    0  7  44.333333 -0.901127  0.265815
# -c:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
infile= r'http://nwis.waterdata.usgs.gov/usa/nwis/qwdata/?site_no=11530500&agency_cd=USGS&inventory_output=0&rdb_inventory_output=file&TZoutput=0&pm_cd_compare=Greater%20than&radio_parm_cds=parm_cd_list&radio_multiple_parm_cds=00665&qw_attributes=0&format=rdb&qw_sample_wide=wide&rdb_qw_attributes=0&date_format=YYYY-MM-DD&rdb_compression=value&submitted_form=brief_list'
response = urllib2.urlopen(infile)
cols = ['datetime','agency','site','end_dt','end_tm','dtm','dtm_cd','coll_ent_cd','medium_cd','tu_id','body_part_id','PO4']

usgsP = pd.read_table(response, skiprows=65, skip_footer=5, na_values=('-','','No Data','No data'),parse_dates={'datetime':[2,3]})#, parse_cols=cols)
usgsP.columns = cols

usgsP.set_index('datetime',inplace=True)
usgsP.drop(['agency','site','end_dt','end_tm','dtm','dtm_cd','coll_ent_cd','medium_cd','tu_id','body_part_id'],axis=1,inplace=True)
usgsP['month'] = usgsP.index.to_datetime().month.astype(int)
usgsP['year'] = usgsP.index.to_datetime().year.astype(int)
usgsP = usgsP[(usgsP['year']>=1972) & (usgsP.index.to_datetime() <= pd.datetime(1979,10,31))]

usgsP.sort(columns=['month','year'],axis=0, inplace=True)

# %%
def mk_ts(df, const, group1, orderby = 'year', alpha = 0.05):
    '''
    df = dataframe
    const = variable tested for trend
    group1 = variable to group by
    orderby = variable to order by (typically a date)
    '''
    
    def mk_test(x, alpha):
        """
        this perform the MK (Mann-Kendall) test to check if there is any trend present in 
        data or not

        Input:
            x:   a vector of data
            alpha: significance level

        Output:
            trend: tells the trend (increasing, decreasing or no trend)
            h: True (if trend is present) or False (if trend is absence)
            p: p value of the sifnificance test
            z: normalized test statistics 

        Examples
        --------
          >>> x = np.random.rand(100)
          >>> trend,h,p,z = mk_test(x,0.05) 

        Credit: http://pydoc.net/Python/ambhas/0.4.0/ambhas.stats/
        """
        n = len(x)

        # calculate S 
        s = 0
        for k in xrange(n-1):
            for j in xrange(k+1,n):
                s += np.sign(x[j] - x[k])

        # calculate the unique data
        unique_x = np.unique(x)
        g = len(unique_x)

        # calculate the var(s)
        if n == g: # there is no tie
            var_s = (n*(n-1)*(2*n+5))/18
        else: # there are some ties in data
            tp = np.zeros(unique_x.shape)
            for i in xrange(len(unique_x)):
                tp[i] = sum(unique_x[i] == x)
            var_s = (n*(n-1)*(2*n+5) - np.sum(tp*(tp-1)*(2*tp+5)))/18

        if s>0:
            z = (s - 1)/np.sqrt(var_s)
        elif s == 0:
            z = 0
        elif s<0:
            z = (s + 1)/np.sqrt(var_s)
        else:
            z = 0

        # calculate the p_value
        p = 2*(1-norm.cdf(abs(z))) # two tail test
        h = abs(z) > norm.ppf(1-alpha/2) 

        if (z<0) and h:
            trend = 'decreasing'
        elif (z>0) and h:
            trend = 'increasing'
        else:
            trend = 'no trend'

        return pd.Series({'trend':trend, 'varS':round(var_s,3), 'p':round(p,3), 'z':round(z,3), 's':round(s,3), 'n':n})

    def zcalc(Sp, Varp):
        if Sp > 0:
            return (Sp - 1)/Varp**0.5
        elif Sp < 0:
            return (Sp + 1)/Varp**0.5
        else:
            return 0   
    
    # attempt to convert text to float for calculations
    if df[const].dtypes == np.object or df[const].dtypes == 'object':
        df[const] = df[const].map(lambda x: x.strip('><E '))
        df[const] = df[const].astype(float)
    elif df[const].dtypes == np.float or df[const].dtypes == np.float64 or df[const].dtypes == np.float32 or df[const].dtypes == np.float16:
        df[const] = df[const]
    elif df[const].dtypes in (np.int,np.int16,np.int32,np.int64):
        df[const] = df[const].astype(float)
    else:
        print "check type of variable"

    # remove null values
    df[const].dropna(inplace=True)
    # remove index
    df.reset_index(inplace=True, drop=True)
    # sort by groups, then time
    df.sort(columns=[group1,orderby],axis=0, inplace=True)
    
    # group by group and apply mk_test
    dg = df.groupby(group1).apply(lambda x: mk_test(x[const].values, alpha))
    Var_S = dg.varS.sum()
    S = dg.s.sum()
    N = dg.n.sum()
    Z = zcalc(S,Var_S)
    P = 2*(1-norm.cdf(abs(Z)))
    group_n = len(dg)
    h = abs(Z) > norm.ppf(1-alpha/2) 

    if (Z<0) and h:
        trend = 'decreasing'
    elif (Z>0) and h:
        trend = 'increasing'
    else:
        trend = 'no trend'
    
    
    return pd.Series({'S':S, 'Z':Z, 'p':P, 'trend':trend, 'group_n':group_n, 'sample_n':N})

# %%
mk_ts(df,const, group1, orderby)
# Out:
#            p   s       trend    varS      z
# month
# 1      0.803  -3    no trend  64.333 -0.249
# 2      0.312  -5    no trend  15.667 -1.011
# 3      0.006 -23  decreasing  64.333 -2.743
# 4      0.021 -23  decreasing  91.000 -2.306
# 5      0.369  -8    no trend  60.667 -0.899
# 6      0.411  -5    no trend  23.667 -0.822
# 7      0.751  -3    no trend  39.667 -0.318
# 8      0.900   2    no trend  63.333  0.126
# 9      0.124 -11    no trend  42.333 -1.537
# 10     0.894  -2    no trend  56.667 -0.133
# 11     1.000   1    no trend   7.667  0.000
# 12     0.366  -7    no trend  44.000 -0.905

# %% [markdown]
# # USGS Scientific Investigations Report 2012–5049

# %% [markdown]
# This is an example from a <a href=http://pubs.usgs.gov/sir/2012/5049/>USGS report</a> examining regional trends of nitrate, chloride, and total dissolved solids over time for various National Water-Quality Assessment (NAWQA) stations.

# %%
The following sheet links directly to the excel spreadsheets provided as appendices to the report.

# %%
infile2 = r'http://pubs.usgs.gov/sir/2012/5049/support/SIR2012_5049_Appendix_2_04022012.xlsx'
response2 = urllib2.urlopen(infile2)
cols = ['site','unit','network','date','time','Nrem','N','Clrem','Cl','TDSrem', 'TDS']
usgsT = pd.read_excel(response2, skiprows=1, skip_footer=5, na_values=('-','','No Data','No data','.'))#, parse_cols=cols)
usgsT.columns = cols
usgsT['strTime'] = usgsT['time'].apply(lambda x: '0000' if np.isnan(x)==True else str(str(int(x)).zfill(4)))
usgsT['strdate'] = usgsT['date'].apply(lambda x: str(x)[:10])
usgsT['datetime'] = pd.to_datetime(usgsT['strdate'] + usgsT['strTime'], format='%Y-%m-%d%H%M', coerce=True)
usgsT.drop(['strTime','strdate'],axis=1,inplace=True)
usgsT.reset_index(inplace=True)
usgsT.set_index('datetime',inplace=True)
usgsT['datetime'] = usgsT.index.to_datetime()
usgsT.sort_index(axis=0, inplace=True)
usgsT['year'] = usgsT.index.to_datetime().year.astype(int)

# %%
combo, names = [],[]
for k, v in usgsT.groupby('network'):
    combo.append(mk_ts(v, 'Cl','site','datetime', 0.10))
    names.append(k)
pd.DataFrame(combo, index=names)
# Out:
#               S         Z  group_n         p  sample_n       trend
# acfbluscr3  NaN  0.000000        5  1.000000        36    no trend
# acfbsus1     26  2.946278        5  0.003216        24  increasing
# albelusag1   12  1.587713        5  0.112351        21    no trend
# cazbsus1a    10  1.006231        5  0.314305        25    no trend
# ccptlusag2b NaN  0.000000        5  1.000000        48    no trend
# ccptlusor1b -15 -1.183216        5  0.236724        30    no trend
# ccptsus1b   NaN  0.000000        5  1.000000        30    no trend
# dlmvluscr1   -2 -0.117851        5  0.906186        24    no trend
# dlmvsus1     16  1.767767        5  0.077100        24  increasing
# eiwaluscr1    6  0.589256        5  0.555690        24    no trend
# eiwasus2     -3 -0.274721        4  0.783530        19    no trend
# lerilusrc1   30  3.242299        5  0.001186        25  increasing
# lerisus1     28  3.018692        5  0.002539        25  increasing
# linjlusrc1   82  4.317315        5  0.000016        41  increasing
# linjsus2     32  2.829900        5  0.004656        28  increasing
# lirbsus1     -4 -0.242800        5  0.808160        31    no trend
# miselusrc1  -23 -1.859339        5  0.062979        30  decreasing
# necblusrc1   12  1.146829        5  0.251452        26    no trend
# nvbrsus2     26  2.362278        6  0.018163        31  increasing
# ozrklusag2a   0  0.000000        5  1.000000        25    no trend
# potolusag1   58  3.382328        6  0.000719        41  increasing
# pugtluscr1   -9 -0.730297        5  0.465209        28    no trend
# pugtlusrs1   18  0.816968        5  0.413947        44    no trend
# rioglusag1   15  1.400000        4  0.161513        23    no trend
# riogluscr1  NaN  0.000000        5  1.000000        34    no trend
# rioglusrc1   -2 -0.125000        5  0.900524        23    no trend
# sacrluscr1  NaN  0.000000        5  1.000000        30    no trend
# sacrlusrc1   -6 -0.441942        5  0.658531        29    no trend
# sanasus2     -1  0.000000        5  1.000000        26    no trend
# sanjluscr1a  22  1.750000        5  0.080118        30  increasing
# sanjlusor1a  40  2.318309        5  0.020433        38  increasing
# sanjlusor2a NaN  0.000000        5  1.000000        32    no trend
# sanjsus1      4  0.257248        6  0.796987        33    no trend
# santlusrc1   27  2.600000        4  0.009322        23  increasing
# santsus2      1  0.000000        5  1.000000        28    no trend
# sctxlusrc1   40  2.163331        5  0.030516        40  increasing
# sctxsus1      8  0.618718        5  0.536102        29    no trend
# sofllusor1    0  0.000000        5  1.000000        23    no trend
# sofllusrc1a  45  2.379248        5  0.017348        40  increasing
# spltluscr1  NaN  0.000000        5  1.000000        29    no trend
# trinsus3      6  0.668153        5  0.504036        22    no trend
# ucollusrc1    0  0.000000        4  1.000000        26    no trend
# uirblusrc1   53  4.163332        5  0.000031        31  increasing
# umisluscr1    2  0.088388        5  0.929568        29    no trend
# umislusrc1    7  0.271329        5  0.786138        44    no trend
# umissus3      2  0.111803        5  0.910979        25    no trend
# usnkluscr2    4  0.145865        7  0.884028        51    no trend
# usnkluscr3  -22 -1.378718        5  0.167982        34    no trend
# whitluscr1  -16 -1.677051        5  0.093533        25  decreasing
# willlusag3   10  0.760639        5  0.446873        30    no trend
# wmiclusag2  -18 -1.900658        5  0.057347        25  decreasing
# wmicsus1     12  1.296362        5  0.194851        24    no trend

# %%
combo, names = [],[]
for k, v in usgsT.groupby('network'):
    combo.append(mk_ts(v, 'TDS','site','datetime', 0.10))
    names.append(k)
pd.DataFrame(combo, index=names)
# Out:
#               S         Z  group_n         p  sample_n       trend
# acfbluscr3  NaN  0.000000        5  1.000000        36    no trend
# acfbsus1     24  2.710576        5  0.006717        24  increasing
# albelusag1    4  0.433013        5  0.665006        21    no trend
# cazbsus1a     4  0.335410        5  0.737316        25    no trend
# ccptlusag2b NaN  0.000000        5  1.000000        48    no trend
# ccptlusor1b -13 -1.014185        5  0.310494        30    no trend
# ccptsus1b   NaN  0.000000        5  1.000000        30    no trend
# dlmvluscr1    2  0.117851        5  0.906186        24    no trend
# dlmvsus1    NaN  0.000000        5  1.000000        24    no trend
# eiwaluscr1  -10 -1.060660        5  0.288844        24    no trend
# eiwasus2    -14 -1.737198        4  0.082352        19  decreasing
# lerilusrc1   32  3.465905        5  0.000528        25  increasing
# lerisus1      4  0.335410        5  0.737316        25    no trend
# linjlusrc1   72  3.791504        5  0.000150        41  increasing
# linjsus2     16  1.369306        5  0.170904        28    no trend
# lirbsus1      1  0.000000        5  1.000000        31    no trend
# miselusrc1  -21 -1.690309        5  0.090969        30  decreasing
# necblusrc1   10  0.938315        5  0.348083        26    no trend
# nvbrsus2     14  1.228385        6  0.219303        31    no trend
# ozrklusag2a  12  1.229837        5  0.218758        25    no trend
# potolusag1   20  1.127443        6  0.259555        41    no trend
# pugtluscr1   -9 -0.730297        5  0.465209        28    no trend
# pugtlusrs1   35  1.635826        5  0.101876        44    no trend
# rioglusag1   13  1.200000        4  0.230139        23    no trend
# riogluscr1  NaN  0.000000        5  1.000000        34    no trend
# rioglusrc1    0  0.000000        5  1.000000        23    no trend
# sacrluscr1  NaN  0.000000        5  1.000000        30    no trend
# sacrlusrc1   12  0.972272        5  0.330915        29    no trend
# sanasus2     -7 -0.600000        5  0.548506        26    no trend
# sanjluscr1a  41  3.333333        5  0.000858        30  increasing
# sanjlusor1a  34  1.961646        5  0.049804        38  increasing
# sanjlusor2a NaN  0.000000        5  1.000000        32    no trend
# sanjsus1    NaN  0.000000        6  1.000000        33    no trend
# santlusrc1    3  0.200000        4  0.841481        23    no trend
# santsus2    -17 -1.485563        5  0.137395        28    no trend
# sctxlusrc1   40  2.163331        5  0.030516        40  increasing
# sctxsus1      6  0.441942        5  0.658531        29    no trend
# sofllusor1   14  1.625000        5  0.104163        23    no trend
# sofllusrc1a  35  1.838509        5  0.065987        40  increasing
# spltluscr1  NaN  0.000000        5  1.000000        29    no trend
# trinsus3     22  2.806243        5  0.005012        22  increasing
# ucollusrc1    4  0.242536        4  0.808365        26    no trend
# uirblusrc1   55  4.323460        5  0.000015        31  increasing
# umisluscr1    6  0.441942        5  0.658531        29    no trend
# umislusrc1  -15 -0.633102        5  0.526667        44    no trend
# umissus3      4  0.335410        5  0.737316        25    no trend
# usnkluscr2    2  0.048622        7  0.961221        51    no trend
# usnkluscr3  -12 -0.722185        5  0.470181        34    no trend
# whitluscr1   -4 -0.335410        5  0.737316        25    no trend
# willlusag3   28  2.281916        5  0.022494        30  increasing
# wmiclusag2    0  0.000000        5  1.000000        25    no trend
# wmicsus1     16  1.767767        5  0.077100        24  increasing

# %%
combo, names = [],[]
for k, v in usgsT.groupby('network'):
    combo.append(mk_ts(v, 'N','site','datetime', 0.10))
    names.append(k)
pd.DataFrame(combo, index=names)
# Out:
#               S         Z  group_n         p  sample_n       trend
# acfbluscr3   45  2.848114        5  0.004398        36  increasing
# acfbsus1     26  2.946278        5  0.003216        24  increasing
# albelusag1   -2 -0.204124        5  0.838256        21    no trend
# cazbsus1a    10  1.006231        5  0.314305        25    no trend
# ccptlusag2b -33 -1.353456        5  0.175910        48    no trend
# ccptlusor1b -35 -2.873524        5  0.004059        30  decreasing
# ccptsus1b    -7 -0.507093        5  0.612090        30    no trend
# dlmvluscr1    8  0.875000        5  0.381574        24    no trend
# dlmvsus1      4  0.433013        5  0.665006        24    no trend
# eiwaluscr1   -7 -0.768221        5  0.442356        24    no trend
# eiwasus2     -7 -1.114172        4  0.265205        19    no trend
# lerilusrc1   10  1.125000        5  0.260589        25    no trend
# lerisus1     -7 -1.664101        5  0.096092        25  decreasing
# linjlusrc1   33  1.823369        5  0.068247        41  increasing
# linjsus2     10  0.883939        5  0.376729        28    no trend
# lirbsus1      0  0.000000        5  1.000000        31    no trend
# miselusrc1    9  0.758190        5  0.448337        30    no trend
# necblusrc1    1  0.000000        5  1.000000        26    no trend
# nvbrsus2     20  1.795331        6  0.072601        31  increasing
# ozrklusag2a  -8 -0.782624        5  0.433848        25    no trend
# potolusag1   40  2.314224        6  0.020655        41  increasing
# pugtluscr1  -28 -2.464752        5  0.013711        28  decreasing
# pugtlusrs1   38  1.778107        5  0.075386        44  increasing
# rioglusag1   -1  0.000000        4  1.000000        23    no trend
# riogluscr1  -30 -2.005972        5  0.044859        34  decreasing
# rioglusrc1   -3 -0.355407        5  0.722284        23    no trend
# sacrluscr1  -13 -1.079082        5  0.280551        30    no trend
# sacrlusrc1  NaN  0.000000        5  1.000000        29    no trend
# sanasus2    -17 -1.600000        5  0.109599        26    no trend
# sanjluscr1a  54  4.416667        5  0.000010        30  increasing
# sanjlusor1a  46  2.674972        5  0.007474        38  increasing
# sanjlusor2a  29  2.134980        5  0.032763        32  increasing
# sanjsus1     36  3.001225        6  0.002689        33  increasing
# santlusrc1   -3 -0.268059        4  0.788654        23    no trend
# santsus2    -13 -2.281394        5  0.022525        28  decreasing
# sctxlusrc1    4  0.166410        5  0.867834        40    no trend
# sctxsus1      0  0.000000        5  1.000000        29    no trend
# sofllusor1   -3 -0.411110        5  0.680992        23    no trend
# sofllusrc1a   0  0.000000        5  1.000000        40    no trend
# spltluscr1  -14 -1.114741        5  0.264962        29    no trend
# trinsus3      6  1.250000        5  0.211300        22    no trend
# ucollusrc1    5  0.323733        4  0.746140        26    no trend
# uirblusrc1   20  1.803400        5  0.071325        31  increasing
# umisluscr1   10  0.795495        5  0.426326        29    no trend
# umislusrc1   60  2.668072        5  0.007629        44  increasing
# umissus3     -4 -0.400892        5  0.688500        25    no trend
# usnkluscr2   64  3.066792        7  0.002164        51  increasing
# usnkluscr3   65  4.201806        5  0.000026        34  increasing
# whitluscr1   -8 -1.237437        5  0.215925        25    no trend
# willlusag3   -7 -0.729395        5  0.465760        30    no trend
# wmiclusag2  -18 -2.003469        5  0.045127        25  decreasing
# wmicsus1      4  0.612372        5  0.540291        24    no trend
