# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import os
import glob
import xmltodict
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import matplotlib.ticker as tick
import seaborn as sns
import scipy.stats as sp
import statsmodels.api as sm
import statsmodels.tsa.tsatools as tools
from pandas.stats.api import ols
from datetime import datetime
from pylab import rcParams
rcParams['figure.figsize'] = 15, 10

# %% [markdown]
# ## Import Relevant Data

# %% [markdown]
# ### Well Information

# %%
wellinfo = pd.read_csv('O:\\Snake Valley Water\\Transducer Data\\Database Archive\\well.csv',header=0,index_col=0)
wellinfo["G_Elev_m"] = wellinfo["GroundElevation"]/3.2808

# %% [markdown]
# ### Manual Water Levels

# %%
manualwls = "O:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\All tape measurements.csv"

# %%
manual = pd.read_csv(manualwls, skiprows=0, parse_dates=0, index_col="DateTime", engine="python")

# %%
# this script removes extra fields from a database download of all mamual measurements
try:
    manual = manual.drop(["ReadingID","MeasuredLevel","Temp","BaroEfficiencyLevel","DeltaLevel","DTWBelowCasing",
                          "DriftCorrection","DTWBelowGroundSurface","WaterElevation","Tape","MeasuredByID"],axis=1)
    manual.to_csv("O:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\All tape measurements.csv")
except(ValueError):
    pass

# %% [markdown]
# ### Barometric Pressure Data

# %% [markdown]
# The script below uses a complete file path with wildcard ending to find all of the relevant files in a directory (folder) to generate a Pandas dataframe of all of the compiled data, with duplicates removed and datetimes sorted.

# %%
def compilation(inputfile):
    """
    This function reads multiple Solinst transducer files in a directory and generates a compiled Pandas dataframe.
    
    inputfile = complete file path to input files; use * for wildcard in file name
        example -> 'O:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\all\\LEV\\*baro*' picks any file containing 'baro'
    
    packages required:
        pandas as pd
        glob
        os
        xmltodict
    """
    
    def getfilename(path):
        # this function extracts the file name without file path or extension
        return path.split('\\').pop().split('/').pop().rsplit('.', 1)[0]
    
    # create empty dictionary to hold dataframes
    f={}

    # generate list of relevant files
    filelist = glob.glob(inputfile)

    # iterate through list of relevant files
    for infile in filelist:
        # get the extension of the input file
        filetype = os.path.splitext(infile)[1]
        # run computations using lev files
        if filetype=='.lev':
            # open text file
            with open(infile) as fd:
                # find beginning of data
                indices = fd.readlines().index('[Data]\n')

            # convert data to pandas dataframe starting at the indexed data line
            f[getfilename(infile)] = pd.read_table(infile, parse_dates=True, sep='     ', index_col=0,
                                           skiprows=indices+2, names=['DateTime','Level','Temperature'], skipfooter=1,engine='python')
            # add extension-free file name to dataframe
            f[getfilename(infile)]['name'] = getfilename(infile)
            
        # run computations using xle files
        elif filetype=='.xle':
            # open text file
            with open(infile) as fd:
                # parse xml
                obj = xmltodict.parse(fd.read(),encoding="ISO-8859-1")
            # navigate through xml to the data
            wellrawdata = obj['Body_xle']['Data']['Log']
            # convert xml data to pandas dataframe
            f[getfilename(infile)] = pd.DataFrame(wellrawdata)
            # get header names and apply to the pandas dataframe          
            f[getfilename(infile)][str(obj['Body_xle']['Ch1_data_header']['Identification']).title()] = f[getfilename(infile)]['ch1']
            f[getfilename(infile)][str(obj['Body_xle']['Ch2_data_header']['Identification']).title()] = f[getfilename(infile)]['ch2']
  
            # add extension-free file name to dataframe
            f[getfilename(infile)]['name'] = getfilename(infile)
            # combine Date and Time fields into one field
            f[getfilename(infile)]['DateTime'] = pd.to_datetime(f[getfilename(infile)].apply(lambda x: x['Date'] + ' ' + x['Time'], 1))
            f[getfilename(infile)] = f[getfilename(infile)].reset_index()
            f[getfilename(infile)] = f[getfilename(infile)].set_index('DateTime')
            f[getfilename(infile)] = f[getfilename(infile)].drop(['Date','Time','@id','ch1','ch2','index','ms'],axis=1)
        # run computations using csv files

        else:
            pass
    # concatonate all of the dataframes in dictionary f to one dataframe: g
    g = pd.concat(f)
    # remove multiindex and replace with index=Datetime
    g = g.reset_index()
    g = g.set_index(['DateTime'])
    # drop old indexes
    g = g.drop(['level_0'],axis=1)
    # remove duplicates based on index then sort by index
    g['ind']=g.index
    g.drop_duplicates(subset='ind',inplace=True)
    g.drop('ind',axis=1,inplace=True)
    g = g.sort()
    # ensure that the Level and Temperature data are in a float format
    g['Level'] = g['Level'].convert_objects(convert_numeric=True)
    g['Temperature'] = g['Temperature'].convert_objects(convert_numeric=True)
    outfile = g
    return outfile

# %% [markdown]
# The appendomatic function below appends new data (infile) onto existing data by parsing the new data and making it the same format as the existing data, then merging the datasets, then overwriting the existing data.

# %%
def appendomatic(infile,existingfile):
     '''
     appends data from one table to an existing compilation
     this tool will delete and replace the existing file
     
     infile = input file
     existingfile = file you wish to append to
     
     '''
    def getfilename(path):
        # this function extracts the file name without file path or extension
        return path.split('\\').pop().split('/').pop().rsplit('.', 1)[0]

    # get the extension of the input file
    filetype = os.path.splitext(infile)[1]
    
    # run computations using lev files
    if filetype=='.lev':
        # open text file
        with open(infile) as fd:
            # find beginning of data
            indices = fd.readlines().index('[Data]\n')

        # convert data to pandas dataframe starting at the indexed data line
        f = pd.read_table(infile, parse_dates=True, sep='     ', index_col=0,
                                       skiprows=indices+2, names=['DateTime','Level','Temperature'], skipfooter=1,engine='python')
        # add extension-free file name to dataframe
        f['name'] = getfilename(infile)

    # run computations using xle files
    elif filetype=='.xle':
        # open text file
        with open(infile) as fd:
            # parse xml
            obj = xmltodict.parse(fd.read(),encoding="ISO-8859-1")
        # navigate through xml to the data
        wellrawdata = obj['Body_xle']['Data']['Log']
        # convert xml data to pandas dataframe
        f = pd.DataFrame(wellrawdata)
        # get header names and apply to the pandas dataframe
        f[str(obj['Body_xle']['Ch1_data_header']['Identification']).title()] = f['ch1']
        f[str(obj['Body_xle']['Ch2_data_header']['Identification']).title()] = f['ch2']

        # add extension-free file name to dataframe
        f['name'] = getfilename(infile)
        # combine Date and Time fields into one field
        f['DateTime'] = pd.to_datetime(f.apply(lambda x: x['Date'] + ' ' + x['Time'], 1))
        f = f.reset_index()
        f = f.set_index('DateTime')
        f = f.drop(['Date','Time','@id','ch1','ch2','index','ms'],axis=1)
    
    # run computations using csv files
    elif filetype=='.csv':
        with open(infile) as fd:
        # find beginning of data
            try:
                indices = fd.readlines().index('Date,Time,ms,Level,Temperature\n')
            except ValueError:
                indices = fd.readlines().index(',Date,Time,100 ms,Level,Temperature\n')
        f = pd.read_csv(infile, skiprows=indices, skipfooter=1, engine='python')
        # add extension-free file name to dataframe
        f['name'] = getfilename(infile)
        # combine Date and Time fields into one field
        f['DateTime'] = pd.to_datetime(f.apply(lambda x: x['Date'] + ' ' + x['Time'], 1))
        f = f.reset_index()
        f = f.set_index('DateTime')
        f = f.drop(['Date','Time','ms','index'],axis=1)
            # skip other file types
    else:
        pass

    # ensure that the Level and Temperature data are in a float format
    f['Level'] = f['Level'].convert_objects(convert_numeric=True)
    f['Temperature'] = f['Temperature'].convert_objects(convert_numeric=True)
    h = pd.read_csv(existingfile,index_col=0,header=0,parse_dates=True)
    g = pd.concat([h,f])
    # remove duplicates based on index then sort by index
    g['ind']=g.index
    g.drop_duplicates(subset='ind',inplace=True)
    g.drop('ind',axis=1,inplace=True)
    g = g.sort()    
    os.remove(exists)
    g.to_csv(exists)

# %%
def list_file_types(folder):

    # generate list of relevant files
    filelist = glob.glob(inputfile)
    
    paths = [os.path.join(path,fn) for fn in next(os.walk(path))[2]]
    
    def getfilename(path):
        # this function extracts the file name without file path or extension
        return path.split('\\').pop().split('/').pop().rsplit('.', 1)[0]

    # get the extension of the input file
    filetype = os.path.splitext(infile)[1]

# %%
#def make_files_table(folder, wellinfofile='O:\\Snake Valley Water\\Transducer Data\\Database Archive\\well.csv'):
'''
This tool will make a descriptive table (Pandas DataFrame) containing filename, date, and site id.
For it to work properly, files must be named in the following fashion:
siteid YYYY-MM-DD
example: pw03a 2015-03-15.csv

This tool assumes that if there are two files with the same name but different extensions, 
then the datalogger for those data is a Solinst datalogger.

folder = directory containing the newly downloaded transducer data
'''
wellinfofile='O:\\Snake Valley Water\\Transducer Data\\Database Archive\\well.csv'
filenames = next(os.walk(folder))[2]
site_id, exten, dates, fullfilename = [],[],[],[]
# parse filename into relevant pieces
for i in filenames:
    site_id.append(i[:-15].lower())
    exten.append(i[-4:])
    dates.append(i[-14:-4])
    fullfilename.append(i)
files = {'siteid':site_id,'extensions':exten,'date':dates,'full_file_name':fullfilename}
files = pd.DataFrame(files)
files['filedups'] = files.duplicated(subset='siteid')
files['LoggerTypeID'] = files['filedups'].astype('int')+1
files['LoggerTypeName']=files['LoggerTypeID'].apply(lambda x: 'Solinst' if x==2 else 'Global Water')
files.drop_duplicates(subset='siteid',take_last=True,inplace=True)

wellinfo = pd.read_csv(wellinfofile,header=0,index_col=0)
wellinfo["G_Elev_m"] = wellinfo["GroundElevation"]/3.2808
wellinfo['Well'] = wellinfo['Well'].apply(lambda x: str(x).lower().strip())
files = pd.merge(files,wellinfo,left_on='siteid',right_on='Well')
files.drop(['filedups','extensions','WRNum',WIN	USGSNumber	Offset	GroundElevation	ScreenInterval	Latitude	Longitude	UTMEasting	UTMNorthing	UTMZone	Section	Township	Range	BMID	POD	RecordStart	RecordEnd	BaroCorrectStart	DateCompleted	WellDescription	BaroLoggerTypeID	ScreenedUnitID	LoggerTypeID	LoggerTypeID	Notes	Private	WellTypeID	BoreholeDepth	LinkWaterRights	LinkLithologicLog	LinkDevelopmentLog	LinkGeophysicalLog	HasTemp	BaroEfficiency	BaroEfficiencyStart	GraphMax	GraphMin	ImagePath	LinkUSGSNWIS	VegType
],axis=1,inplace=True)

# 57  2015-03-03       .xle                  sg24a 2015-03-03.xle
# 58  2015-03-03       .xle                  sg24b 2015-03-03.xle
# 59  2015-03-03       .xle                  sg24c 2015-03-03.xle
# 60  2015-03-04       .xle                  sg25a 2015-03-04.xle
# 61  2015-03-04       .xle                  sg25b 2015-03-04.xle
# 62  2015-03-04       .xle                  sg25c 2015-03-04.xle
# 63  2015-03-04       .xle                  sg25d 2015-03-04.xle
# 64  2015-03-04       .xle                  sg26a 2015-03-04.xle
# 65  2015-03-03       .xle                   sg27 2015-03-03.xle
# 66  2015-03-03       .xle  snake valley north mx 2015-03-03.xle
# 67  2015-03-02       .xle  snake valley south mx 2015-03-02.xle
#
#                    siteid  LoggerTypeID_x LoggerTypeName  SiteID  \
# 0                   ag13a               2        Solinst      13
# 1                   ag13b               2        Solinst      13
# 2                   ag13c               2        Solinst      13
# 3                   ag14a               1   Global Water      14
# 4                   ag14b               1   Global Water      14
# 5                   ag14c               2        Solinst      14
# 6                    ag15               1   Global Water      15
# 7                   ag16a               2        Solinst      16
# 8                   ag16b               2        Solinst      16
# 9                   ag16c               2        Solinst      16
# 10        central tule mx               2        Solinst      33
# 11       coyote knolls mx               2        Solinst      34
# 12             eskdale mx               1   Global Water      31
# 13                  pw01a               2        Solinst       1
# 14                  pw01b               2        Solinst       1
# 15                  pw01c               1   Global Water       1
# 16                  pw02b               2        Solinst       2
# 17                  pw03a               2        Solinst       3
# 18                  pw03b               2        Solinst       3
# 19                  pw03z               2        Solinst       3
# 20                  pw04a               1   Global Water       4
# 21                  pw04b               1   Global Water       4
# 22                  pw05a               2        Solinst       5
# 23                  pw05b               1   Global Water       5
# 24                  pw05c               1   Global Water       5
# 25                  pw06a               1   Global Water       6
# 26                  pw06b               2        Solinst       6
# 27                  pw06c               1   Global Water       6
# 28                  pw06d               1   Global Water       6
# 29                 pw06mx               2        Solinst       6
# ..                    ...             ...            ...     ...
# 38                  pw10b               1   Global Water      10
# 39                  pw11b               1   Global Water      11
# 40                  pw11c               1   Global Water      11
# 41                  pw11d               2        Solinst      11
# 42                  pw11e               2        Solinst      11
# 43                   pw12               2        Solinst      12
# 44                  pw17a               1   Global Water      17
# 45                  pw17b               2        Solinst      17
# 46                  pw17c               1   Global Water      17
# 47                  pw19a               2        Solinst      19
# 48                  pw19b               1   Global Water      19
# 49                  pw19c               2        Solinst      19
# 50                   pw20               2        Solinst      20
# 51                  sg21a               2        Solinst      21
# 52                  sg21b               2        Solinst      21
# 53                  sg21c               2        Solinst      21
# 54                  sg22a               2        Solinst      22
# 55                  sg22b               2        Solinst      22
# 56                  sg23b               2        Solinst      23
# 57                  sg24a               2        Solinst      24
# 58                  sg24b               2        Solinst      24
# 59                  sg24c               2        Solinst      24
# 60                  sg25a               2        Solinst      25
# 61                  sg25b               2        Solinst      25
# 62                  sg25c               2        Solinst      25
# 63                  sg25d               2        Solinst      25
# 64                  sg26a               2        Solinst      26
# 65                   sg27               2        Solinst      27
# 66  snake valley north mx               2        Solinst      29
# 67  snake valley south mx               2        Solinst      30
#
#                      Well           WRNum     WIN     ...       \
# 0                   ag13a   0818006M00(1)  431489     ...
# 1                   ag13b   0818006M00(2)  431490     ...
# 2                   ag13c   0818006M00(2)  431490     ...
# 3                   ag14a   0818005M00(1)  431476     ...
# 4                   ag14b   0818005M00(2)  431477     ...
# 5                   ag14c   0818005M00(2)  431477     ...
# 6                    ag15      0819001M00  431630     ...
# 7                   ag16a   0818007M00(1)  431758     ...
# 8                   ag16b   0818007M00(2)  431629     ...
# 9                   ag16c   0818007M00(2)  431629     ...
# 10        central tule mx             NaN     NaN     ...
# 11       coyote knolls mx             NaN     NaN     ...
# 12             eskdale mx             NaN     NaN     ...
# 13                  pw01a   0718001M00(1)  430279     ...
# 14                  pw01b   0718001M00(1)  430279     ...
# 15                  pw01c   0718001M00(1)  430279     ...
# 16                  pw02b   0818011M00(2)  431934     ...
# 17                  pw03a   0718002M00(2)  430534     ...
# 18                  pw03b   0718002M00(2)  430534     ...
# 19                  pw03z   0818010M00(2)  431726     ...
# 20                  pw04a  0718001M00(10)  430319     ...
# 21                  pw04b  0718001M00(10)  430319     ...
# 22                  pw05a   0718001M00(4)  430214     ...
# 23                  pw05b   0718001M00(4)  430214     ...
# 24                  pw05c   0718001M00(4)  430214     ...
# 25                  pw06a   0718002M00(1)  430533     ...
# 26                  pw06b   0718002M00(1)  430533     ...
# 27                  pw06c   0718002M00(1)  430533     ...
# 28                  pw06d      0718004M00  430535     ...
# 29                 pw06mx             NaN     NaN     ...
# ..                    ...             ...     ...     ...
# 38                  pw10b      0718005M00  430934     ...
# 39                  pw11b      0818003M00  431169     ...
# 40                  pw11c      0818003M00  431169     ...
# 41                  pw11d   0818001M00(2)  431166     ...
# 42                  pw11e   0818001M00(2)  431166     ...
# 43                   pw12      0818004M00  431289     ...
# 44                  pw17a   0818014M00(1)  431965     ...
# 45                  pw17b   0818014M00(2)  431964     ...
# 46                  pw17c   0818014M00(2)  431964     ...
# 47                  pw19a   0818012M00(1)  431865     ...
# 48                  pw19b   0818012M00(2)  431864     ...
# 49                  pw19c   0818012M00(1)  431865     ...
# 50                   pw20      0818013M00  431866     ...
# 51                  sg21a   0818016M00(1)  432029     ...
# 52                  sg21b   0818016M00(2)  432028     ...
# 53                  sg21c    0818016M0(3)  432027     ...
# 54                  sg22a   0818015M00(1)  432032     ...
# 55                  sg22b   0818015M00(2)  432031     ...
# 56                  sg23b      0818018M00     NaN     ...
# 57                  sg24a   0818019M00(1)  432096     ...
# 58                  sg24b   0818019M00(2)  432097     ...
# 59                  sg24c   0818019M00(3)  432098     ...
# 60                  sg25a      0818025M00  432242     ...
# 61                  sg25b   0818023M00(1)  432140     ...
# 62                  sg25c   0818023M00(2)  432141     ...
# 63                  sg25d   0818023M00(3)  432142     ...
# 64                  sg26a   0818021M00(3)  432243     ...
# 65                   sg27      0818024M00  432277     ...
# 66  snake valley north mx             NaN     NaN     ...
# 67  snake valley south mx             NaN     NaN     ...
#
#                                    LinkGeophysicalLog  HasTemp  \
# 0   http://geology.utah.gov/databases/groundwater/...        0
# 1   http://geology.utah.gov/databases/groundwater/...        1
# 2   http://geology.utah.gov/databases/groundwater/...        0
# 3   http://geology.utah.gov/databases/groundwater/...        0
# 4   http://geology.utah.gov/databases/groundwater/...        0
# 21              Snake Valley images/Site 04 photo.jpg
# 22              Snake Valley images/Site 05 photo.jpg
# 23              Snake Valley images/Site 05 photo.jpg
# 24              Snake Valley images/Site 05 photo.jpg
# 25              Snake Valley images/Site 06 photo.jpg
# 26              Snake Valley images/Site 06 photo.jpg
# 27              Snake Valley images/Site 06 photo.jpg
# 28              Snake Valley images/Site 06 photo.jpg
# 29              Snake Valley images/Site 06 photo.jpg
# ..                                                ...
# 38              Snake Valley images/Site 10 photo.jpg
# 39              Snake Valley images/Site 11 photo.jpg
# 40              Snake Valley images/Site 11 photo.jpg
# 41              Snake Valley images/Site 11 photo.jpg
# 42              Snake Valley images/Site 11 photo.jpg
# 43              Snake Valley images/Site 12 photo.jpg
# 44              Snake Valley images/Site 17 photo.jpg
# 45              Snake Valley images/Site 17 photo.jpg
# 46              Snake Valley images/Site 17 photo.jpg
# 47              Snake Valley images/Site 19 photo.jpg
# 48              Snake Valley images/Site 19 photo.jpg
# 49              Snake Valley images/Site 19 photo.jpg
# 50              Snake Valley images/Site 20 photo.jpg
# 51              Snake Valley images/Site 21 photo.jpg
# 52              Snake Valley images/Site 21 photo.jpg
# 53              Snake Valley images/Site 21 photo.jpg
# 54              Snake Valley images/Site 22 photo.jpg
# 55              Snake Valley images/Site 22 photo.jpg
# 56              Snake Valley images/Site 23 photo.jpg
# 57   Snake Valley images/Twin Springs Wells photo.jpg
# 58   Snake Valley images/Twin Springs Wells photo.jpg
# 59   Snake Valley images/Twin Springs Wells photo.jpg
# 60              Snake Valley images/Site 25 photo.jpg
# 61              Snake Valley images/Site 25 photo.jpg
# 62              Snake Valley images/Site 25 photo.jpg
# 63             Snake Valley images/Site 25D photo.jpg
# 64              Snake Valley images/Site 26 photo.jpg
# 65              Snake Valley images/Site 27 photo.jpg
# 66  Snake Valley images/Snake Valley North MX phot...
# 67  Snake Valley images/Snake Valley South MX phot...
#
#                                          LinkUSGSNWIS VegType     G_Elev_m
# 0                                                 NaN     NaN  1604.425750
# 1                                                 NaN     NaN  1603.907584
# 2                                                 NaN     NaN  1603.907584
# 3                                                 NaN     NaN  1527.188491
# 4                                                 NaN     NaN  1527.005608
# 5                                                 NaN     NaN  1527.005608
# 6                                                 NaN     NaN  1685.076811
# 7                                                 NaN     NaN  1650.664472
# 8                                                 NaN     NaN  1650.359668
# 9                                                 NaN     NaN  1650.359668
# 10  http://nwis.waterdata.usgs.gov/nwis/gwlevels/?...     NaN  1366.252134
# 11  http://nwis.waterdata.usgs.gov/nwis/gwlevels/?...     NaN  1393.196781
# 12  http://nwis.waterdata.usgs.gov/nwis/gwlevels/?...     NaN  1536.881248
# 13                                                NaN     NaN  1619.330651
# 14                                                NaN     NaN  1619.330651
# 15                                                NaN     NaN  1619.330651
# 16                                                NaN     NaN  1664.014874
# 17                                                NaN     NaN  1623.079737
# 18                                                NaN     NaN  1623.079737
# 19                                                NaN     NaN  1618.690563
# 20                                                NaN     NaN  1883.747866
# 21                                                NaN     NaN  1883.747866
# 22                                                NaN     NaN  1548.311387
# 23                                                NaN     NaN  1548.311387
# 24                                                NaN     NaN  1548.311387
# 25                                                NaN     NaN  1524.292855
# 26                                                NaN     NaN  1524.292855
# 27                                                NaN     NaN  1524.292855
# 28                                                NaN     NaN  1524.170934
# 29  http://nwis.waterdata.usgs.gov/nwis/gwlevels/?...     NaN  1516.428920
# ..                                                ...     ...          ...
# 38                                                NaN     NaN  1605.187759
# 39                                                NaN     NaN  1726.712997
# 40                                                NaN     NaN  1726.712997
# 41                                                NaN     NaN  1725.036576
# 42                                                NaN     NaN  1725.036576
# 43                                                NaN     NaN  1783.436967
# 44                                                NaN     NaN  1373.902707
# 45                                                NaN     NaN  1373.719824
# 46                                                NaN     NaN  1373.719824
# 47                                                NaN     NaN  1412.673738
# 48                                                NaN     NaN  1411.942209
# 49                                                NaN     NaN  1412.673738
# 50                                                NaN     NaN  1439.039259
# 51                                                NaN     NaN  1313.612534
# 52                                                NaN     NaN  1313.643014
# 53                                                NaN     NaN  1313.582053
# 54                                                NaN     NaN  1315.654718
# 55                                                NaN     NaN  1315.959522
# 56                                                NaN     NaN  1661.271641
# 57                                                NaN     NaN  1468.970983
# 58                                                NaN     NaN  1469.001463
# 59                                                NaN     NaN  1469.184345
# 60                                                NaN     NaN  1459.704950
# 61                                                NaN     NaN  1459.704950
# 62                                                NaN     NaN  1459.735430
# 63                                                NaN     NaN  1461.564253
# 64                                                NaN     NaN  1461.472812
# 65                                                NaN     NaN  1470.220678
# 66  http://nwis.waterdata.usgs.gov/nwis/gwlevels/?...     NaN  1553.310168
# 67  http://nwis.waterdata.usgs.gov/nwis/gwlevels/?...     NaN  1701.383809
#
# [68 rows x 49 columns]

# %%
def get_transducer_headers(inputfile):def get_transducer_headers(inputfile):
    wellrawinfo = obj['Body_xle']['Instrument_info']
    wellrawinfo2 = obj['Body_xle']['Instrument_info_data_header']
    wellinfo = pd.Series(wellrawinfo)
    wellinfo2 = pd.Series(wellrawinfo2)
    wellinfo = pd.concat([wellinfo,wellinfo2],axis=0)
    wellinfodf = pd.DataFrame(wellinfo).transpose()
    #wellinfodf = wellinfodf.set_index('Location')
    wellinfodf

# %% [markdown]
# #### PW10 Barometric Pressure Data

# %%
pw10baro_files = "O:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\all\\XLE\\pw10 baro*"
pw10baro = compilation(pw10baro_files)
pw10baro['Level'].plot()
plt.title('PW10 Barometric Pressure')
plt.ylabel('Pressure (ft)')

pw10baro.to_csv("O:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\pw10baro.csv")

# %% [markdown]
# #### PW03 Barometric Pressure Data

# %%
pw03baro_files = "O:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\all\\XLE\\pw03 baro*"
pw03baro = compilation(pw03baro_files)
pw03baro['Level'].plot()
plt.title('PW03 Barometric Pressure')
plt.ylabel('Pressure (ft)')

pw03baro.to_csv("O:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\pw03baro.csv")

# %%
exists = "O:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\all\\pw03baro.csv"
append = "O:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\2012\\2012 q1\\pw03baro 2012-02-29.csv"
appendomatic(append,exists)

# %%
pw03baro = pd.read_csv(exists,index_col=0)
pw03baro['Level'].plot()

# %% [markdown]
# #### PW19 Barometric Pressure Data

# %%
pw19baro_files = "O:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\all\\XLE\\pw19 baro*"
pw19baro = compilation(pw19baro_files)
pw19baro['Level'].plot()
plt.title('PW19 Barometric Pressure')
plt.ylabel('Pressure (ft)')

pw19baro.to_csv("O:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\pw19baro.csv")

# %% [markdown]
# #### Compilation of Barometric Pressure Data

# %%
pw03baro['pw03'] = pw03baro['Level']
pw10baro['pw10'] = pw10baro['Level']
pw19baro['pw19'] = pw19baro['Level']
baro = pd.merge(pw03baro,pw10baro,how="outer",left_index=True,right_index=True)
baro = pd.merge(baro,pw19baro,how="outer",left_index=True,right_index=True)
baro.dropna(axis=0,inplace=True)
baro['integr'] = 0 #for vented transducers

# %%
barometers = {'barom':['pw03','pw10','pw19'], 'X':[240327.49,271127.67,305088.9], 
              'Y':[4314993.95,4356071.98,4389630.71], 'Z':[1623.079737,1605.187759,1412.673738]}
barolocal = pd.DataFrame(barometers)
barolocal = barolocal.reset_index()
barolocal.set_index('barom',inplace=True)
barolocal
#barolocal.drop(1,inplace=True)
# Out:
#        index          X           Y            Z
# barom
# pw03       0  240327.49  4314993.95  1623.079737
# pw10       1  271127.67  4356071.98  1605.187759
# pw19       2  305088.90  4389630.71  1412.673738

# %%
wellinfo['pw03'] = np.sqrt((barolocal.loc['pw03','X']-wellinfo['UTMEasting'])**2 + 
                               (barolocal.loc['pw03','Y']-wellinfo['UTMNorthing'])**2 + 
                               (barolocal.loc['pw03','Z']-wellinfo['G_Elev_m'])**2)
wellinfo['pw10'] = np.sqrt((barolocal.loc['pw10','X']-wellinfo['UTMEasting'])**2 + 
                               (barolocal.loc['pw10','Y']-wellinfo['UTMNorthing'])**2 + 
                               (barolocal.loc['pw10','Z']-wellinfo['G_Elev_m'])**2)
wellinfo['pw19'] = np.sqrt((barolocal.loc['pw19','X']-wellinfo['UTMEasting'])**2 + 
                               (barolocal.loc['pw19','Y']-wellinfo['UTMNorthing'])**2 + 
                               (barolocal.loc['pw19','Z']-wellinfo['G_Elev_m'])**2)
wellinfo['closest_baro'] = wellinfo[['pw03','pw10','pw19']].T.idxmin()

# %% [markdown]
# ## Water Level Tranducer Data

# %% [markdown]
# ### Import Data

# %%
infile = "O:\\Snake Valley Water\\Transducer Data\\Raw_data_archive\\2015\\2015 q1\\pw01a 2015-03-03.xle"

def getfilename(path):
    # this function extracts the file name without file path or extension
    return path.split('\\').pop().split('/').pop().rsplit('.', 1)[0]

wellid = wellinfo[wellinfo['Well']==getfilename(infile)[0:5].strip().upper()].index.values[0]

# open text file
with open(infile) as fd:
    # parse xml
    obj = xmltodict.parse(fd.read(),encoding="ISO-8859-1")
# navigate through xml to the data
wellrawdata = obj['Body_xle']['Data']['Log']
# convert xml data to pandas dataframe
f = pd.DataFrame(wellrawdata)
# get header names and apply to the pandas dataframe
f[str(obj['Body_xle']['Ch1_data_header']['Identification']).title()] = f['ch1']
f[str(obj['Body_xle']['Ch2_data_header']['Identification']).title()] = f['ch2']
# add extension-free file name to dataframe
f['name'] = getfilename(infile)
# combine Date and Time fields into one field
f['DateTime'] = pd.to_datetime(f.apply(lambda x: x['Date'] + ' ' + x['Time'], 1))
f[str(obj['Body_xle']['Ch1_data_header']['Identification']).title()] = f[str(obj['Body_xle']['Ch1_data_header']['Identification']).title()].convert_objects(convert_numeric=True)
f[str(obj['Body_xle']['Ch2_data_header']['Identification']).title()] = f[str(obj['Body_xle']['Ch2_data_header']['Identification']).title()].convert_objects(convert_numeric=True)
f = f.reset_index()
f = f.set_index('DateTime')
f = f.drop(['Date','Time','@id','ch1','ch2','index','ms'],axis=1)

# %% [markdown]
# ### Match Barometric Data

# %%
barologtype ={1:'integr',2:'pw03',3:'pw10',4:'pw19',5:'pw25',6:'twin',7:'courthouse'}
bse = f.index.to_datetime().minute[0]
#btype = wellinfo.loc[wellid,'closest_baro']
#b = baro[btype]
btype = int(wellinfo[wellinfo.index==wellid]['BaroLoggerTypeID'])
b = baro[barologtype.get(btype)]
b = b.resample('1Min', how='mean')
b = b.interpolate(method='time')
b = b.resample('60Min', how='mean', base=bse)
b = b.to_frame()

# %%
g = pd.merge(f,b,left_index=True,right_index=True,how='inner')
g.columns
# Out:
# Index([u'Level', u'Temperature', u'name', u'pw03'], dtype='object')

# %%
g['wtr_abv'] = g['Level'] - g[barologtype.get(btype)]
g['wtr_abv'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Get Barometric Efficiency

# %%
be = wellinfo[wellinfo.index==wellid]['BaroEfficiency']
be = be.iloc[0]
g['BaroEfficiencyCorrected'] = g['wtr_abv'] + be*g['wtr_abv']

# %%
g['DeltaLevel'] = g['BaroEfficiencyCorrected'] - g['BaroEfficiencyCorrected'][0]

# %% [markdown]
# ### Remove Drift

# %% [markdown]
# http://stackoverflow.com/questions/9877391/how-to-get-the-closest-single-row-after-a-specific-datetime-index-using-python-p
# http://stackoverflow.com/questions/15115547/find-closest-row-of-dataframe-to-given-time-in-pandas

# %%
print max(f.index.to_datetime())
print min(f.index.to_datetime())

# %%
def fcl(df, dtObj):
    '''
    df = dataframe
    dtObj = date object
    '''
    return df.iloc[np.argmin(np.abs(df.index.to_pydatetime() - dtObj))]

# %%
g['MeasuredDTW'] = fcl(manual[manual['WellID']== wellid],min(g.index.to_datetime()))[1]-g['DeltaLevel']
lastdtw = g['MeasuredDTW'][-1]

lastdtw

# %%
wellinfo.columns

# %%
last = fcl(manual[manual['WellID']== wellid],max(g.index.to_datetime()))[1]
first = fcl(manual[manual['WellID']== wellid],min(g.index.to_datetime()))[1]
lastg = float(g[g.index.to_datetime()==max(g.index.to_datetime())]['MeasuredDTW'].values)
driftlen = len(g.index)
g['last_diff_int'] = (last-lastg)/driftlen
g['DriftCorrection'] = g['last_diff_int'].cumsum()-g['last_diff_int']
g['DTWBelowCasing'] = g['DriftCorrection'] + g['MeasuredDTW']
g['DTWBelowGroundSurface'] = g['DTWBelowCasing'] - wellinfo[wellinfo.index==wellid]['Offset']
g['WaterElevation'] = wellinfo[wellinfo.index==wellid]['GroundElevation'] - g['DTWBelowGroundSurface']
print last
print first
print last-lastg
print last_diff_int
print g['drift_corr']
