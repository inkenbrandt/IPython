# %%
import pandas as pd
import numpy as np
import scipy
from scipy import stats
from scipy.stats import norm
import statsmodels as sm
import os
import glob
import re
import xmltodict
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import matplotlib.ticker as tick
from matplotlib.backends.backend_pdf import PdfPages
from datetime import datetime
from pylab import rcParams
rcParams['figure.figsize'] = 15, 10
import urllib2

# %%
import rpy2
# %load_ext rmagic

# %%
# %matplotlib inline
from lifelines.estimation import KaplanMeierFitter
kmf = KaplanMeierFitter()

# %%
infile = r'http://raw.githubusercontent.com/inkenbrandt/IPython/master/Sample_Na.csv'
response = urllib2.urlopen(infile)
df = pd.read_csv(response, index_col=['SampleDate'], parse_dates=True)

# %% [markdown]
# http://stackoverflow.com/questions/10458493/pandas-how-to-plot-yearly-data-on-top-of-each-other <br>
#
# http://stackoverflow.com/questions/29834873/use-python-pandas-to-match-sample-pairs-yearly-data
#
# * drop duplicates
# * aggregate data to monthly via median

# %%
df = df.drop_duplicates()

# %%
y1 = 1960
y2 = 1980
span = str(int((y2-y1)*12))+'M'
print span
# Out:
# 240M

# %%
df['year'] = df.index.to_datetime().year.astype(int)
df['month'] = df.index.to_datetime().month.astype(int)
df['day'] = df.index.to_datetime().day.astype(int)
df3 = df.loc[(df['month'] < 13) & (df['month'] > 0)]
df4 = df3.loc[(df3['year'] <= y2) & (df3['year'] >= y1)]

# %%
df4.reset_index(inplace=True)

# %%
df4['SampleDate'].max()
# Out:
# Timestamp('1980-12-31 00:00:00')

# %%
try:
    df2 = df4.pivot_table(values='ResultValue', 
                         index= 'SampleDate', 
                         columns='StationId').resample(span, how='median',closed='left',  convention='s')
except(MemoryError):
    print("Sample Too Large!")
    pass
    #df2.interpolate(method='time',inplace=True)

# %%
df2.dropna(inplace=True,axis=1)

# %%
wilco = df2.stack().unstack([0])
cols = list(wilco.columns)
wilco.columns = str(y1),str(y2)
wilcodiff = (wilco[str(y2)] - wilco[str(y1)]).median()

# %%
T, p = scipy.stats.wilcoxon(wilco[str(y1)],wilco[str(y2)])
n = len(wilco[str(y1)])
print n , T, p, wilcodiff
if n<23:
    print('Warning: Sample Too Small')
# Out:
# 887 129308.5 2.30291427281e-10 -1.0

# %% [markdown]
# # USGS Data

# %% [markdown]
# http://pubs.usgs.gov/sir/2012/5049/

# %% [markdown]
# ## Decadal Data: Wilcoxan-Pratt Signed-Rank Analysis

# %%
infile2 = r'http://pubs.usgs.gov/sir/2012/5049/support/SIR2012_5049_Appendix_1_04022012.xlsx'
response2 = urllib2.urlopen(infile2)
cols = ['site','unit','network','use','aquifer','rock','depth','date','time','Nrem','N','Clrem','Cl','TDSrem', 'TDS', 'date1','time1','Nrem1','N1','Clrem1','Cl1','TDSrem1','TDS1']

usgs = pd.read_excel(response2, skiprows=1, skip_footer=5, na_values=('-','','No Data','No data'))#, parse_cols=cols)

usgs.columns = cols

# %%
def USGSchemTab(df,chem,group):
    def func(y,x):
        # make conc nulls match value nulls
        if np.isnan(x)==True:
            return np.nan
        elif y=='<':
            return 0
        else:
            return 1
    
    df[chem+'cond'] = usgs.apply(lambda df: func(df[chem+'rem'],df[chem]),axis=1)
    df[chem+'cond1'] = usgs.apply(lambda df: func(df[chem+'rem1'],df[chem]),axis=1)
    
    df.set_index([group],inplace=True)
    unit = df.index.get_level_values(0).unique()
    
    network,n,T1,p1,chng = [],[],[],[],[]
    for i in unit:
        network.append(i)
        n.append(len(df.loc[i,chem]))
        T1.append(scipy.stats.wilcoxon(df.loc[i,chem].values,df.loc[i,chem+'1'].values, zero_method='zsplit')[0])
        p1.append(scipy.stats.wilcoxon(df.loc[i,chem].values,df.loc[i,chem+'1'].values, zero_method='zsplit')[1])
        chng.append(round((df.loc[i,chem+'1'] - df.loc[i,chem]).median(),2))
    refdict = {'ntwrk':network,'n':n,'T':T1,'p':p1,'chng':chng}
    df.reset_index(inplace=True)
    Nresframe = pd.DataFrame(refdict)
    Nresframe['signif'] = Nresframe['p'].apply(lambda x: np.nan if x >= 0.1 else '(+)')
    
    return Nresframe

# %%
NitrateTable = USGSchemTab(usgs,'N','network')
ClTable = USGSchemTab(usgs,'Cl','network')
TDSTable = USGSchemTab(usgs,'TDS','network')

# %% [markdown]
# ### Fit a Distribution for Trumbull

# %% [markdown]
# http://www.sph.umich.edu/dioxin/PDF/Beijing%202009/Gillespie%20Dioxin2009_Turnbull_slides_v2.pdf

# %% [markdown]
# http://stackoverflow.com/questions/6620471/fitting-empirical-distribution-to-theoretical-ones-with-scipy-python

# %%
def dropMDL(x,MDL):
    data = []
    for i in x:
        if i <= MDL:
            pass
        else:
            data.append(i)
    return np.array(data)

# %%
N = dropMDL(usgs['N'].dropna().values,.1)

Nmean = N.mean()
rate = 1./Nmean
Nmax = N.max()
concRange = np.arange(.1,Nmax,0.1)
dt = Nmax/100.

# %%
usgs
# Out:
#          network             site  unit            use  \
# 0     acfbluscr3  305641084542001  ACFB         UNUSED
# 1     acfbluscr3  310552084435601  ACFB         UNUSED
# 2     acfbluscr3  310604084351901  ACFB         UNUSED
# 3     acfbluscr3  310752085271301  ACFB         UNUSED
# 4     acfbluscr3  310913084195301  ACFB         UNUSED
# 5     acfbluscr3  311015084511901  ACFB         UNUSED
# 6     acfbluscr3  311141084513401  ACFB         UNUSED
# 7     acfbluscr3  311505085140101  ACFB         UNUSED
# 8     acfbluscr3  312119084215601  ACFB         UNUSED
# 9     acfbluscr3  312346084520401  ACFB         UNUSED
# 10    acfbluscr3  312908084151901  ACFB         UNUSED
# 11    acfbluscr3  313415084475201  ACFB         UNUSED
# 12    acfbluscr3  314040084110201  ACFB         UNUSED
# 13    acfbluscr3  314357084380001  ACFB         UNUSED
# 14    acfbluscr3  314858084194901  ACFB         UNUSED
# 15    acfbluscr3  315009083571001  ACFB         UNUSED
# 16    acfbluscr3  320001084032801  ACFB         UNUSED
# 17    acfbluscr3  320011084121501  ACFB         UNUSED
# 18    acfbluscr3  320051084061401  ACFB         UNUSED
# 19      acfbsus1  304421084561201  ACFB  INSTITUTIONAL
# 20      acfbsus1  305133084461201  ACFB       DOMESTIC
# 21      acfbsus1  305148084364801  ACFB       DOMESTIC
# 22      acfbsus1  305356084534601  ACFB         UNUSED
# 23      acfbsus1  305705084484201  ACFB    AQUACULTURE
# 24      acfbsus1  305853085135401  ACFB    AQUACULTURE
# 25      acfbsus1  310132085024001  ACFB         UNUSED
# 26      acfbsus1  310427084591101  ACFB         UNUSED
# 27      acfbsus1  310804084455501  ACFB       DOMESTIC
# 28      acfbsus1  311348084282401  ACFB  INSTITUTIONAL
# 29      acfbsus1  311802084192302  ACFB         UNUSED
# ...          ...              ...   ...            ...
# 1205  wmiclusag2  443921089152001  WMIC         UNUSED
# 1206  wmiclusag2  444910089140401  WMIC         UNUSED
# 1207  wmiclusag2  445052088552801  WMIC         UNUSED
# 1208  wmiclusag2  445556089045701  WMIC         UNUSED
# 1209  wmiclusag2  450242089065401  WMIC         UNUSED
# 1210    wmicsus1  434004089100701  WMIC       DOMESTIC
# 1211    wmicsus1  434745089184801  WMIC  INSTITUTIONAL
# 1212    wmicsus1        OTHR-1425  WMIC  PUBLIC SUPPLY
# 1213    wmicsus1  435354088460901  WMIC       DOMESTIC
# 1214    wmicsus1  435515088193101  WMIC       DOMESTIC
# 1215    wmicsus1  435602089165401  WMIC       DOMESTIC
# 1216    wmicsus1  440015089053301  WMIC       DOMESTIC
# 1217    wmicsus1        OTHR-1444  WMIC  PUBLIC SUPPLY
# 1218    wmicsus1  441015088515501  WMIC       DOMESTIC
# 1219    wmicsus1  441948088223301  WMIC        DEWATER
# 1220    wmicsus1        OTHR-1498  WMIC  PUBLIC SUPPLY
# 1221    wmicsus1  442912088224101  WMIC       DOMESTIC
# 1222    wmicsus1  444158088263601  WMIC       DOMESTIC
# 1223    wmicsus1  444834088232201  WMIC       DOMESTIC
# 1224    wmicsus1  445504088094101  WMIC       DOMESTIC
# 1225    wmicsus1        OTHR-1620  WMIC  PUBLIC SUPPLY
# 1226    wmicsus1  451154087361501  WMIC       DOMESTIC
# 1227    wmicsus1  453101087414901  WMIC       DOMESTIC
# 1228    wmicsus1        OTHR-1696  WMIC  PUBLIC SUPPLY
# 1229    wmicsus1  454215087304301  WMIC       DOMESTIC
# 1230    wmicsus1  454622087114801  WMIC       DOMESTIC
# 1231    wmicsus1  454932087063601  WMIC       DOMESTIC
# 1232    wmicsus1  455902087064701  WMIC  INSTITUTIONAL
# 1233    wmicsus1  460418087185501  WMIC       DOMESTIC
# 1234    wmicsus1  461427087171001  WMIC       DOMESTIC
#
#                                  aquifer  \
# 0                Floridan aquifer system
# 1                Floridan aquifer system
# 2                Floridan aquifer system
# 3                Floridan aquifer system
# 4               Surficial aquifer system
# 5                Floridan aquifer system
# 6                Floridan aquifer system
# 7                Floridan aquifer system
# 8               Surficial aquifer system
# 9                Floridan aquifer system
# 10               Floridan aquifer system
# 11              Surficial aquifer system
# 12               Floridan aquifer system
# 13               Floridan aquifer system
# 14               Floridan aquifer system
# 15               Floridan aquifer system
# 16              Surficial aquifer system
# 17               Floridan aquifer system
# 18               Floridan aquifer system
# 19               Floridan aquifer system
# 20               Floridan aquifer system
# 21               Floridan aquifer system
# 22               Floridan aquifer system
# 23               Floridan aquifer system
# 24               Floridan aquifer system
# 25               Floridan aquifer system
# 26               Floridan aquifer system
# 27               Floridan aquifer system
# 28               Floridan aquifer system
# 29               Floridan aquifer system
# ...                                  ...
# 1205              Glacial aquifer system
# 25          1   686.0  0.445344
# 26          1   486.0  0.607287
# 27          1   686.0  0.445344
# 28          1   657.0  0.468826
# 29          1   387.5  0.687045
# ...       ...     ...       ...
# 1205        1  1104.5  0.106478
# 1206        1   101.5  0.918623
# 1207        1   972.0  0.213765
# 1208        1   929.0  0.248583
# 1209        1    75.0  0.940081
# 1210        1    75.0  0.940081
# 1211        1   672.5  0.456275
# 1212        1   657.0  0.468826
# 1213        1  1104.5  0.106478
# 1214        1  1104.5  0.106478
# 1215        1   507.5  0.589879
# 1216        1    33.5  0.973684
# 1217        1  1104.5  0.106478
# 1218        1   436.0  0.647773
# 1219        1   725.0  0.413765
# 1220        1  1104.5  0.106478
# 1221        1  1104.5  0.106478
# 1222        1  1104.5  0.106478
# 1223        1  1104.5  0.106478
# 1224        1   872.5  0.294332
# 1225        1  1104.5  0.106478
# 1226        1  1104.5  0.106478
# 1227        1  1104.5  0.106478
# 1228        1  1104.5  0.106478
# 1229        1  1104.5  0.106478
# 1230        1  1104.5  0.106478
# 1231        1  1104.5  0.106478
# 1232        1  1104.5  0.106478
# 1233        1  1104.5  0.106478
# 1234        1   862.0  0.302834
#
# [1235 rows x 31 columns]

# %%
usgs1 = usgs[usgs['N']>0.1]
plt.hist((usgs1['N'].dropna().values), normed=True)
xmin, xmax = plt.xlim()
x = np.arange(xmin, xmax, 0.01)
p = norm.pdf(x, (usgs1['N']).mean(), (usgs1['N']).std())
plt.plot(x,p,'k')
plt.show()

# %% [markdown]
# http://stackoverflow.com/questions/21887625/python-empirical-distribution-function-ecdf-implementation

# %%
usgs['rank'] = usgs['N'].rank(ascending = 0)
usgs['ecdf_r']=(len(usgs)-usgs['rank']+1)/len(usgs)
usgs
# Out:
#          network             site  unit            use  \
# 0     acfbluscr3  305641084542001  ACFB         UNUSED
# 1     acfbluscr3  310552084435601  ACFB         UNUSED
# 2     acfbluscr3  310604084351901  ACFB         UNUSED
# 3     acfbluscr3  310752085271301  ACFB         UNUSED
# 4     acfbluscr3  310913084195301  ACFB         UNUSED
# 5     acfbluscr3  311015084511901  ACFB         UNUSED
# 6     acfbluscr3  311141084513401  ACFB         UNUSED
# 7     acfbluscr3  311505085140101  ACFB         UNUSED
# 8     acfbluscr3  312119084215601  ACFB         UNUSED
# 9     acfbluscr3  312346084520401  ACFB         UNUSED
# 10    acfbluscr3  312908084151901  ACFB         UNUSED
# 11    acfbluscr3  313415084475201  ACFB         UNUSED
# 12    acfbluscr3  314040084110201  ACFB         UNUSED
# 13    acfbluscr3  314357084380001  ACFB         UNUSED
# 14    acfbluscr3  314858084194901  ACFB         UNUSED
# 15    acfbluscr3  315009083571001  ACFB         UNUSED
# 16    acfbluscr3  320001084032801  ACFB         UNUSED
# 17    acfbluscr3  320011084121501  ACFB         UNUSED
# 18    acfbluscr3  320051084061401  ACFB         UNUSED
# 19      acfbsus1  304421084561201  ACFB  INSTITUTIONAL
# 20      acfbsus1  305133084461201  ACFB       DOMESTIC
# 21      acfbsus1  305148084364801  ACFB       DOMESTIC
# 22      acfbsus1  305356084534601  ACFB         UNUSED
# 23      acfbsus1  305705084484201  ACFB    AQUACULTURE
# 24      acfbsus1  305853085135401  ACFB    AQUACULTURE
# 25      acfbsus1  310132085024001  ACFB         UNUSED
# 26      acfbsus1  310427084591101  ACFB         UNUSED
# 27      acfbsus1  310804084455501  ACFB       DOMESTIC
# 28      acfbsus1  311348084282401  ACFB  INSTITUTIONAL
# 29      acfbsus1  311802084192302  ACFB         UNUSED
# ...          ...              ...   ...            ...
# 1205  wmiclusag2  443921089152001  WMIC         UNUSED
# 1206  wmiclusag2  444910089140401  WMIC         UNUSED
# 1207  wmiclusag2  445052088552801  WMIC         UNUSED
# 1208  wmiclusag2  445556089045701  WMIC         UNUSED
# 1209  wmiclusag2  450242089065401  WMIC         UNUSED
# 1210    wmicsus1  434004089100701  WMIC       DOMESTIC
# 1211    wmicsus1  434745089184801  WMIC  INSTITUTIONAL
# 1212    wmicsus1        OTHR-1425  WMIC  PUBLIC SUPPLY
# 1213    wmicsus1  435354088460901  WMIC       DOMESTIC
# 1214    wmicsus1  435515088193101  WMIC       DOMESTIC
# 1215    wmicsus1  435602089165401  WMIC       DOMESTIC
# 1216    wmicsus1  440015089053301  WMIC       DOMESTIC
# 1217    wmicsus1        OTHR-1444  WMIC  PUBLIC SUPPLY
# 1218    wmicsus1  441015088515501  WMIC       DOMESTIC
# 1219    wmicsus1  441948088223301  WMIC        DEWATER
# 1220    wmicsus1        OTHR-1498  WMIC  PUBLIC SUPPLY
# 1221    wmicsus1  442912088224101  WMIC       DOMESTIC
# 1222    wmicsus1  444158088263601  WMIC       DOMESTIC
# 1223    wmicsus1  444834088232201  WMIC       DOMESTIC
# 1224    wmicsus1  445504088094101  WMIC       DOMESTIC
# 1225    wmicsus1        OTHR-1620  WMIC  PUBLIC SUPPLY
# 1226    wmicsus1  451154087361501  WMIC       DOMESTIC
# 1227    wmicsus1  453101087414901  WMIC       DOMESTIC
# 1228    wmicsus1        OTHR-1696  WMIC  PUBLIC SUPPLY
# 1229    wmicsus1  454215087304301  WMIC       DOMESTIC
# 1230    wmicsus1  454622087114801  WMIC       DOMESTIC
# 1231    wmicsus1  454932087063601  WMIC       DOMESTIC
# 1232    wmicsus1  455902087064701  WMIC  INSTITUTIONAL
# 1233    wmicsus1  460418087185501  WMIC       DOMESTIC
# 1234    wmicsus1  461427087171001  WMIC       DOMESTIC
#
#                                  aquifer  \
# 0                Floridan aquifer system
# 1                Floridan aquifer system
# 2                Floridan aquifer system
# 3                Floridan aquifer system
# 4               Surficial aquifer system
# 5                Floridan aquifer system
# 6                Floridan aquifer system
# 7                Floridan aquifer system
# 8               Surficial aquifer system
# 9                Floridan aquifer system
# 10               Floridan aquifer system
# 11              Surficial aquifer system
# 12               Floridan aquifer system
# 13               Floridan aquifer system
# 14               Floridan aquifer system
# 15               Floridan aquifer system
# 16              Surficial aquifer system
# 17               Floridan aquifer system
# 18               Floridan aquifer system
# 19               Floridan aquifer system
# 20               Floridan aquifer system
# 21               Floridan aquifer system
# 22               Floridan aquifer system
# 23               Floridan aquifer system
# 24               Floridan aquifer system
# 25               Floridan aquifer system
# 26               Floridan aquifer system
# 27               Floridan aquifer system
# 21          1   544.5  0.559919
# 22          1   380.5  0.692713
# 23          1   517.0  0.582186
# 24          1   387.5  0.687045
# 25          1   686.0  0.445344
# 26          1   486.0  0.607287
# 27          1   686.0  0.445344
# 28          1   657.0  0.468826
# 29          1   387.5  0.687045
# ...       ...     ...       ...
# 1205        1  1104.5  0.106478
# 1206        1   101.5  0.918623
# 1207        1   972.0  0.213765
# 1208        1   929.0  0.248583
# 1209        1    75.0  0.940081
# 1210        1    75.0  0.940081
# 1211        1   672.5  0.456275
# 1212        1   657.0  0.468826
# 1213        1  1104.5  0.106478
# 1214        1  1104.5  0.106478
# 1215        1   507.5  0.589879
# 1216        1    33.5  0.973684
# 1217        1  1104.5  0.106478
# 1218        1   436.0  0.647773
# 1219        1   725.0  0.413765
# 1220        1  1104.5  0.106478
# 1221        1  1104.5  0.106478
# 1222        1  1104.5  0.106478
# 1223        1  1104.5  0.106478
# 1224        1   872.5  0.294332
# 1225        1  1104.5  0.106478
# 1226        1  1104.5  0.106478
# 1227        1  1104.5  0.106478
# 1228        1  1104.5  0.106478
# 1229        1  1104.5  0.106478
# 1230        1  1104.5  0.106478
# 1231        1  1104.5  0.106478
# 1232        1  1104.5  0.106478
# 1233        1  1104.5  0.106478
# 1234        1   862.0  0.302834
#
# [1235 rows x 31 columns]

# %%
dist = scipy.stats.expon.pdf(concRange, scale = 1./rate)

# %%
nbins = 200
plt.figure(figsize=(5,3));
plt.hist(N, nbins);
plt.plot(concRange, dist*len(N)*Nmax/nbins,
         '-r', lw=3);
#plt.xlim(-.10,.50)

# %%
size = 30000
x = scipy.arange(size)
y = scipy.int_(scipy.round_(scipy.stats.vonmises.rvs(5,size=size)*47))
h = plt.hist(y, bins=range(48), color='w')

dist_names = ['gamma',  'rayleigh', 'norm']# 'pareto','beta',]

for dist_name in dist_names:
    dist = getattr(scipy.stats, dist_name)
    param = dist.fit(y)
    pdf_fitted = dist.pdf(x, *param[:-2], loc=param[-2], scale=param[-1]) * size
    plt.plot(pdf_fitted, label=dist_name)
    plt.xlim(0,47)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## Decadal Data: Time Series Analysis

# %%
infile2 = r'http://pubs.usgs.gov/sir/2012/5049/support/SIR2012_5049_Appendix_2_04022012.xlsx'
response2 = urllib2.urlopen(infile2)
cols = ['site','unit','network','date','time','Nrem','N','Clrem','Cl','TDSrem', 'TDS']

usgsT = pd.read_excel(response2, skiprows=1, skip_footer=5, na_values=('-','','No Data','No data','.'))#, parse_cols=cols)

usgsT.columns = cols
usgsT
# Out:
#                  site  unit     network       date  time Nrem       N Clrem  \
# 0     310552084435601  ACFB  acfbluscr3 1993-08-25  1510  NaN   4.700   NaN
# 1     310552084435601  ACFB  acfbluscr3 1994-04-05  1400  NaN   5.200   NaN
# 2     310552084435601  ACFB  acfbluscr3 1999-09-15  1000  NaN   6.981   NaN
# 3     310552084435601  ACFB  acfbluscr3 2002-04-11  1600  NaN   7.970   NaN
# 4     310552084435601  ACFB  acfbluscr3 2005-07-21  1100  NaN  11.671   NaN
# 5     310552084435601  ACFB  acfbluscr3 2007-08-15  1045  NaN  12.731   NaN
# 6     310552084435601  ACFB  acfbluscr3 2009-08-18  1400  NaN  12.898   NaN
# 1537  441948088223301  WMIC    wmicsus1 2002-05-29  1030  NaN   0.797   NaN
# 1538  441948088223301  WMIC    wmicsus1 2005-06-13  1630  NaN   0.901   NaN
# 1539  441948088223301  WMIC    wmicsus1 2007-05-30  1150  NaN   0.835   NaN
# 1540  441948088223301  WMIC    wmicsus1 2009-06-18   945  NaN   0.860   NaN
# 1541  444158088263601  WMIC    wmicsus1 1995-06-15   930    <   0.059   NaN
# 1542  444158088263601  WMIC    wmicsus1 2002-06-26  1400    <   0.059   NaN
# 1543  444158088263601  WMIC    wmicsus1 2005-06-14   945    <   0.059   NaN
# 1544  444158088263601  WMIC    wmicsus1 2007-05-30  1530    <   0.059   NaN
# 1545  444158088263601  WMIC    wmicsus1 2009-06-16  1545    <   0.059   NaN
# 1546  451154087361501  WMIC    wmicsus1 1995-06-15  1430    <   0.059   NaN
# 1547  451154087361501  WMIC    wmicsus1 2002-06-25  1000    <   0.059   NaN
# 1548  451154087361501  WMIC    wmicsus1 2005-06-15  1215    <   0.059   NaN
# 1549  451154087361501  WMIC    wmicsus1 2007-05-31  1015    <   0.059   NaN
# 1550  451154087361501  WMIC    wmicsus1 2009-06-17   915    <   0.059   NaN
# 1551  454622087114801  WMIC    wmicsus1 1995-06-20  1340    <   0.059   NaN
# 1552  454622087114801  WMIC    wmicsus1 2002-06-11  1000    <   0.059   NaN
# 1553  454622087114801  WMIC    wmicsus1 2005-06-14  1800    <   0.059   NaN
# 1554  454622087114801  WMIC    wmicsus1 2007-05-31  1555    <   0.059   NaN
# 1555  454622087114801  WMIC    wmicsus1 2009-07-28  1515    <   0.059   NaN
#
#           Cl  TDSrem      TDS
# 0      3.800     NaN   153.00
# 1      4.200     NaN   135.00
# 2        NaN     NaN      NaN
# 3      5.250     NaN   151.84
# 4      5.873     NaN   225.81
# 5      6.318     NaN   232.14
# 6      7.028     NaN   245.30
# 7      3.600     NaN   133.00
# 8      3.700     NaN   136.00
# 9        NaN     NaN      NaN
# 10     3.210     NaN   146.14
# 11     3.835     NaN   161.85
# 12     3.625     NaN   152.92
# 13     4.485     NaN   181.52
# 14     4.200     NaN   139.00
# 15     3.500     NaN   148.00
# 16       NaN     NaN      NaN
# 17     3.630     NaN   125.19
# 18     4.632     NaN   153.60
# 19     4.013     NaN   159.58
# 20     4.390     NaN   146.84
# 21     2.500     NaN    60.00
# 22     2.200     NaN    50.00
# 23       NaN     NaN      NaN
# 24     2.440     NaN    23.43
# 25     2.136     NaN    37.77
# 26     2.195     NaN    42.71
# 27     2.214     NaN    37.91
# 28     3.100     NaN   118.00
# 29     2.900     NaN   120.00
# ...      ...     ...      ...
# 1526   4.005     NaN   210.86
# 1527  36.000     NaN   485.00
# 1528  15.840     NaN   379.60
# 1529   5.509     NaN   384.08
# 1530   8.488     NaN   419.57
# 1531  17.445     NaN   402.21
# 1532   5.680     NaN   264.53
# 1533   5.938     NaN   261.02
# 1534   6.414     NaN   250.79
# 1535   7.251     NaN   278.93
# 1536   1.500     NaN   302.00
# 1537   2.410     NaN   303.18
# 1538   1.741     NaN   312.04
# 1539   2.010     NaN   324.01
# 1540   2.199     NaN   300.60
# 1541   0.900     NaN   331.00
# 1542   1.710     NaN   346.48
# 1543   1.226     NaN   342.07
# 1544   1.254     NaN   346.85
# 1545   1.430     NaN   351.82
# 1546  71.000     NaN  2800.00
# 1547  67.170     NaN  2862.69
# 1548  68.366     NaN  2813.73
# 1549  64.297     NaN  2811.70
# 1550  65.837     NaN  2845.61
# 1551   6.500     NaN   246.00
# 1552   7.150     NaN   297.27
# 1553   6.774     NaN   255.21
# 1554   6.703     NaN   262.23
# 1555   7.266     NaN   267.12
#
# [1556 rows x 11 columns]

# %%
def mk_test(x, alpha = 0.05):
    """
    this perform the MK (Mann-Kendall) test to check if there is any trend present in 
    data or not
    
    Input:
        x:   a vector of data
        alpha: significance level
    
    Output:
        trend: tells the trend (increasing, decreasing or no trend)
        h: True (if trend is present) or False (if trend is absence)
        p: p value of the sifnificance test
        z: normalized test statistics 
        
    Examples
    --------
      >>> x = np.random.rand(100)
      >>> trend,h,p,z = mk_test(x,0.05) 
      
    Credit: http://pydoc.net/Python/ambhas/0.4.0/ambhas.stats/
    """
    n = len(x)
    
    # calculate S 
    s = 0
    for k in xrange(n-1):
        for j in xrange(k+1,n):
            s += np.sign(x[j] - x[k])
    
    # calculate the unique data
    unique_x = np.unique(x)
    g = len(unique_x)
    
    # calculate the var(s)
    if n == g: # there is no tie
        var_s = (n*(n-1)*(2*n+5))/18
    else: # there are some ties in data
        tp = np.zeros(unique_x.shape)
        for i in xrange(len(unique_x)):
            tp[i] = sum(unique_x[i] == x)
        var_s = (n*(n-1)*(2*n+5) + np.sum(tp*(tp-1)*(2*tp+5)))/18
    
    if s>0:
        z = (s - 1)/np.sqrt(var_s)
    elif s == 0:
        z = 0
    elif s<0:
        z = (s + 1)/np.sqrt(var_s)
    else:
        z = 0
    
    # calculate the p_value
    p = 2*(1-norm.cdf(abs(z))) # two tail test
    h = abs(z) > norm.ppf(1-alpha/2) 
    
    if (z<0) and h:
        trend = 'decreasing'
    elif (z>0) and h:
        trend = 'increasing'
    else:
        trend = 'no trend'
        
    return trend, h, p, z

# %%
def USGStimechem(df,chem,group):
    def func(y,x):
        # make conc nulls match value nulls
        if np.isnan(x)==True:
            return np.nan
        elif y=='<':
            return 0
        else:
            return 1
    
    df[chem+'cond'] = usgs.apply(lambda df: func(df[chem+'rem'],df[chem]),axis=1)
     
    df.set_index([group],inplace=True)
    unit = df.index.get_level_values(0).unique()
    
    network,n,T1,p1 = [],[],[],[]
    for i in unit:
        network.append(i)
        n.append(len(df.loc[i,chem]))
        T1.append(mk_test(df.loc[i,chem].values)[3])
        p1.append(mk_test(df.loc[i,chem].values)[2])

    refdict = {'ntwrk':network,'n':n,'T':T1,'p':p1}
    df.reset_index(inplace=True)
    Nresframe = pd.DataFrame(refdict)
    Nresframe['signif'] = Nresframe['p'].apply(lambda x: np.nan if x >= 0.1 else '(+)')
    
    return Nresframe

# %%
df.loc[i,chem].values

# %%
tabN = USGStimechem(usgsT,"N","network")
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-94-68a43cdb3848> in <module>()
# ----> 1 tabN = USGStimechem(usgsT,"N","network")
#
# <ipython-input-86-37399859f520> in USGStimechem(df, chem, group)
#      18         network.append(i)
#      19         n.append(len(df.loc[i,chem]))
# ---> 20         T1.append(mk_test(df.loc[i,chem].values)[3])
#      21         p1.append(mk_test(df.loc[i,chem].values)[2])
#      22
#
# <ipython-input-92-a61b940076ee> in mk_test(x, alpha)
#      50
#      51     # calculate the p_value
# ---> 52     p = 2*(1-norm.cdf(abs(z))) # two tail test
#      53     h = abs(z) > norm.ppf(1-alpha/2)
#      54
#
# UnboundLocalError: local variable 'z' referenced before assignment

# %%
usgs.loc[usgs['N'][usgs['network']=='acfbluser3'].dropna().values
# Out:
# array([], dtype=float64)

# %% [markdown]
# # R Analysis

# %% [markdown]
# Dealing with censored (below detection limit) data using the R package "NADA"

# %%
usgs.sort(columns=['N'],inplace=True)
nitrate = usgs['N'].dropna().values.tolist()
nitrateCen = usgs['Ncond'].dropna().values.tolist()
nitrCen, grp = [], []
nit = []
for i in nitrate:
    nit.append(np.log(i))

for i in nitrateCen:
    grp.append(1)
    if i > 0.0:
        nitrCen.append(False)
    else:
        nitrCen.append(True)
#nitrate = nit
#nitrate

# %%
from rpy2.robjects.packages import importr
nada = importr('NADA')

# %%
class cenfit(RS4):
  __metaclass__ = RS4Auto_Type
  __rname__ = 'cenfit'
  __rpackagename__ = 'NADA'

# %%
nitrate = rpy2.robjects.vectors.FloatVector(nitrate)
nitrCen = rpy2.robjects.vectors.BoolVector(nitrCen)
nitrateCen = nada.Cen(nitrate,nitrCen, type = 'left')
km = nada.cenfit(nitrate,nitrCen)
print km
# Out:
#   File "<ipython-input-154-629a6d68b288>", line 5
#     print km@mean
#             ^
# SyntaxError: invalid syntax

# %%
# %%R  -i nitrate,nitrCen,grp -o s,km,ros,pykm_mean,stats
# library(NADA)
# data(ShePyrene)
# attach(ShePyrene)
# #PyreneCen
# grp <- c(grp)
# nitrate <- c(nitrate)
# nitrCen <- c(nitrCen)
# ShePyrene$Pyrene
# s <- capture.output({censummary(nitrate,nitrCen, groups=grp)})
# pykm = cenfit(nitrate,nitrCen)
# km <- capture.output({cenfit(nitrate,nitrCen)})
# pyros = cenros(nitrate,nitrCen)
# ros <- capture.output({cenros(nitrate,nitrCen)})
# pymle <- cenmle(nitrate,nitrCen,dist='lognormal')
# mle <- capture.output({cenmle(nitrate,nitrCen)})
# plot(pykm)
# plot(pyros)
# plot(pymle)
# cenboxplot(nitrate,nitrCen)
# stats <- capture.output({censtats(nitrate,nitrCen)})
# pykm_mean <- capture.output({mean(pykm)})

# %%
def rPrint(x):
    for line in x:
        print(line)

# %%
rPrint(s)
# Out:
# 1
# all:
#          n      n.cen    pct.cen        min        max
# 1232.00000  266.00000   21.59091    0.05000   55.00000
#
# limits:
#   limit   n uncen   pexceed
# 1  0.05 253    62 0.7861678
# 2  0.10  13   904 0.7337662

# %%
rPrint(stats)
# Out:
#          n      n.cen    pct.cen
# 1232.00000  266.00000   21.59091
#        median      mean         sd
# K-M 1.6000000  4.131901   6.489090
# ROS 1.6110000  4.143822   6.480966
# MLE 0.7358198 18.783114 479.104435

# %%
rPrint(pykm_mean)
labs = pykm_mean[0].strip().split(None)
stats= [float(i) for i in pykm_mean[1].split(' ')[:-1]]
statsdic = dict(zip(labs,stats))
statsdic['mean']
usgs[usgs['N']>0.050].mean()
# Out:
#      mean        se   0.95LCL   0.95UCL
# 4.1319005 0.1848751 3.7695520 4.4942491
# depth        132.195847
# time        1207.332992
# N              5.203176
# Cl            40.240957
# TDSrem              NaN
# TDS          396.970021
# time1       1227.508197
# N1             5.731590
# Cl1           46.846267
# TDS1         412.954253
# Ncond          0.986680
# N1cond         0.935052
# TDScond        1.000000
# TDS1cond       0.998970
# Clcond         0.998974
# Cl1cond        1.000000
# dtype: float64

# %% [markdown]
# # Other Stuff

# %%
print(df.groupby(['StationId']).resample('M', how='mean').head(n=20))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#months = df.index.get_level_values(2).unique()
stations = df.index.get_level_values(0).unique()
#dates = df.index.get_level_values(3).unique()
for i in stations:
    df.loc[i,:].resample('M',how='mean')

# %%
months = df.index.get_level_values(2).unique()
stations = df.index.get_level_values(1).unique()
dates = df.index.get_level_values(3).unique()
for i in stations:
    for j in  months:
        for h in df1.loc[(i,j),'nextyeardate']:
            print df1.ix[df1.loc[(i,j),'SampleDate'].searchsorted(h)].values
            #print df1.loc[np.argmin(np.abs(df1.loc[(i,j),'SampleDate'] - h))]
            #print h

# %%
df.groupby(index.resample('M', how='mean')

# %%
df1 = df.groupby(['StationId']).resample('M', how='mean')
print(df1.head(n=5))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = pd.read_csv(testfile, index_col='SampleDate',parse_dates=True)

# %%
df['year'] = df.index.to_datetime().year.astype(int)
df['month'] = df.index.to_datetime().month.astype(int)
df['day'] = df.index.to_datetime().day.astype(int)
df = df.loc[(df['month'] < 13) & (df['month'] > 0)]
df = df.loc[(df['year'] < 2100) & (df['year'] > 1850)]

# %%
df['nextyear'] = np.sum((df['year'],1)).astype(int)
df['nextyeardate'] = df[['nextyear','month','day']].apply(lambda x: pd.datetime(x[0],x[1],x[2]-1) if x[2]>28 else pd.datetime(x[0],x[1],x[2]),1)

# %%
df.reset_index(inplace=True)
df.set_index(['Param','StationId','month'],inplace=True)

# %%
df1 = df.loc['Calcium']
df1.loc[(stations[0],months[0],dates[0]),'ResultValue']
# Out:
# StationId      month  SampleDate
# USGS-09380000  1      1926-01-11    108
# Name: ResultValue, dtype: float64

# %%
#df1.loc[(stations[2],months[4]),'nextyeardate'].values.astype(datetime)
#df1.loc[(stations[2],months[4]),'SampleDate'].astype(datetime)[1]
df1.loc[(stations[0],months[0]),'SampleDate'].searchsorted(pd.datetime(1926,1,1))
# Out:
# array([0])

# %%
df1 = df[df.Param=='Calcium' & df.index.month==1.0]
a = df1.groupby(['StationId','Param',df.index.day]).mean()
print len(a)
station = []
months = []
for i in range(len(a)):
    if a[i]>10:
        station.append((a.index[i][0]))
        months.append((a.index[i][2]))

# %%
a = df1.groupby(['StationId','Param',df.index.day]).mean()

# %%
months[1]
df1['month']=df1.index.to_datetime().month
df1['year']=df1.index.to_datetime().year
df1['day']=df1.index.to_datetime().day
# Out:
# -c:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df2 = df1[df1['StationId'].isin(station) & df1['month'].isin(months)]

# %%
df3 = df1.drop_duplicates(subset=['StationId','year','month'])

# %%
df4 = df3.groupby(['StationId'])
df4
