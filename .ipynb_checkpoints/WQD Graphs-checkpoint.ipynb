# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams
import urllib2
# allow figures to display in this browser
# %matplotlib inline 
# adjust default figure size
rcParams['figure.figsize'] = 12, 8

# %% [markdown]
# Import data using the `urllib2` library.  Put imported data into a Pandas Dataframe structure.

# %%
infile = r'https://raw.githubusercontent.com/inkenbrandt/IPython/master/graphexamples.csv'
response = urllib2.urlopen(infile)
df = pd.read_csv(response, index_col=['SampleDate'], parse_dates=True)

# %% [markdown]
# View the first 10 rows of the imported data to see the data structure.  This will obviously not be a part of the UI.

# %%
df.head(10)
# Out:
#               Param                 ParamGroup ProjectId ResultStatus  \
# SampleDate
# 1926-01-11  Calcium  Inorganics, Major, Metals      USGS   Historical
# 1926-02-25  Calcium  Inorganics, Major, Metals      USGS   Historical
# 1926-03-26  Calcium  Inorganics, Major, Metals      USGS   Historical
# 1926-05-24  Calcium  Inorganics, Major, Metals      USGS   Historical
# 1926-06-01  Calcium  Inorganics, Major, Metals      USGS   Historical
# 1926-06-07  Calcium  Inorganics, Major, Metals      USGS   Historical
# 1926-06-13  Calcium  Inorganics, Major, Metals      USGS   Historical
# 1926-06-20  Calcium  Inorganics, Major, Metals      USGS   Historical
# 1926-07-10  Calcium  Inorganics, Major, Metals      USGS   Historical
# 1926-07-11  Calcium  Inorganics, Major, Metals      USGS   Historical
#
#             ResultValue            SampleId      SampMedia      StationId  \
# SampleDate
# 1926-01-11          108  nwisaz.01.92600001  Surface Water  USGS-09380000
# 1926-02-25          100  nwisaz.01.92600002  Surface Water  USGS-09380000
# 1926-03-26           66  nwisaz.01.92600003  Surface Water  USGS-09380000
# 1926-05-24           49  nwisaz.01.92600004  Surface Water  USGS-09380000
# 1926-06-01           38  nwisaz.01.92600005  Surface Water  USGS-09380000
# 1926-06-07           46  nwisaz.01.92600006  Surface Water  USGS-09380000
# 1926-06-13           36  nwisaz.01.92600007  Surface Water  USGS-09380000
# 1926-06-20           39  nwisaz.01.92600008  Surface Water  USGS-09380000
# 1926-07-10           58  nwisaz.01.92600009  Surface Water  USGS-09380000
# 1926-07-11           61  nwisaz.01.92600010  Surface Water  USGS-09380000
#
#             Unit  USGSPCode
# SampleDate
# 1926-01-11  mg/l        915
# 1926-02-25  mg/l        915
# 1926-03-26  mg/l        915
# 1926-05-24  mg/l        915
# 1926-06-01  mg/l        915
# 1926-06-07  mg/l        915
# 1926-06-13  mg/l        915
# 1926-06-20  mg/l        915
# 1926-07-10  mg/l        915
# 1926-07-11  mg/l        915

# %% [markdown]
# The main plot I am interested in is a histogram.  Histograms show the number of occurences for ranges of concentrations.  Some libraries, such as the one I am using, can calculate the bin size automatically. I have made two histograms using the same data.  One has more bins than the other.  See the <a href=http://en.wikipedia.org/wiki/Histogram>wikipedia article</a> for more information.

# %%
y = df.ResultValue.values

plt.figure()
plt.hist(y)
plt.xlabel('Concentration (mg/L)')
plt.ylabel('Count')
plt.title('Calcium')

# %%
y = df.ResultValue.values

plt.figure()
plt.hist(y, bins=50)
plt.xlabel('Concentration (mg/L)')
plt.ylabel('Count')
plt.title('Calcium')

# %% [markdown]
# The other plot I want is a time-series scatter plot, showing time on the x-axis and chemical concentration on the y-axis.  This plot should show only one parameter at a time if possible.

# %%
y = df.ResultValue.values
x = df.index.to_datetime().values

plt.figure()
plt.scatter(x,y)
plt.xlim('1/1/1915','1/1/1950')
plt.ylim(0,400)
plt.xlabel('Date')
plt.ylabel('Concentration (mg/L)')
plt.title('Calcium')
